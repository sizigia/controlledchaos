# %%
from nltk.stem import SnowballStemmer
import spacy
import string
import re
from tika import parser
import os
import re
from datetime import datetime
from bs4 import BeautifulSoup
import chardet
import textract
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from collections import Counter, defaultdict
from sklearn.utils.extmath import randomized_svd
import pickle
import os
import pymongo
from dotenv import load_dotenv
from datetime import datetime

nlp = spacy.load('en_core_web_lg')
punctuation = '!"$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'
custom_sw = pickle.load(open('../app/data/stopwords.pkl', 'rb'))
custom_sw.extend(['want'])
formats = pickle.load(open('../app/data/formats.pkl', 'rb'))

# %%
def get_attributes(filepath, folder):
    if not folder.endswith('/'):
        folder = folder + '/'

    file = folder + filepath
    file_stats = os.stat(file)
    attributes = {'parent_folder': folder,
                  'absolute_path': file,
                  'name': filepath,
                  'size_mb': file_stats.st_size / 1e+6,
                  'created_on': datetime.fromtimestamp(file_stats.st_birthtime),
                  'last_modified_on': datetime.fromtimestamp(file_stats.st_mtime)}

    if os.path.isdir(file):
        ext = 'folder'
    elif os.path.isfile(file):
        ext = filepath.split('.')[-1]
    else:
        ext = ''

    attributes['extension'] = ext

    return attributes


def blind_categories(format_dict, files):
    blind_classifier = {}

    for k, v in format_dict.items():
        blind_classifier[k] = [e for e in files if (e['extension'] in v)]

    blind_classifier['folders'] = [
        e for e in files if (e['extension'] == 'folder')]
    return blind_classifier


def extract_text(record, thresh=50000):
    text_ext = ['ppt', 'pptx', 'doc', 'docx', 'odt', 'pdf',
                'rtf', 'text', 'txt', 'wpd', 'ods']

    if record['extension'] in text_ext:
        text = parser.from_file(record['absolute_path'], service='text')[
            'content']
    
    text = text.replace('\n', ' ')
    text = re.sub('[#]\w+', ' ', text)
    text = re.sub('\d+', '', text)
    for p in punctuation:
        text = text.replace(p, ' ')
        
    if (len(text) < thresh):
        return text
    else:
        return text[:thresh]


def labels(corpus, nclusters=10):
    params = {
        'vectorizer': {
            'analyzer': 'word',
            'stop_words': stopwords.words('english'),
            'ngram_range': (1, 1),
            'token_pattern': '[a-z]{3,}',
            'max_df': 0.1,
            'lowercase': True
        },
        'km_params': {
            'random_state': 30,
            'n_clusters': nclusters,
        }
    }

    tfidf = TfidfVectorizer(**params['vectorizer'])
    try:
        X = tfidf.fit_transform(corpus)
        km = KMeans(**params['km_params']).fit(X)
        return km.labels_
    except:
        return 404


def name_cluster_labels_common(sw, topic_files, words=8):

    label_text = ' '.join([file['preproc_text'] for file in topic_files])
    corpus = re.findall('[a-zA-Z]{4,}', label_text)
    corpus = [w for w in corpus if (w.lower() not in sw)]
    label_dict = Counter(corpus)
    cluster_name = '-'.join([w[0] for w in label_dict.most_common(words)])

    return cluster_name


def get_topic_files(files):
    topic_files = defaultdict(list)

    for file in files:
        topic_files[file['topic']].append(file)

    topic_files = dict(topic_files)

    return topic_files



def preprocessing(text):
    text = text.replace('\n', ' ')
    text = re.sub('[#]\w+', ' ', text)
    text = re.sub('\d+', '', text)
    for p in punctuation:
        text = text.replace(p, ' ')
    
    sent = []
    doc = nlp(text)
    
    for word in doc:
        sent.append(word.lemma_)
    
    return " ".join(sent).replace('-PRON-', '')


def stemming(text, all_stopwords=custom_sw):
    stemmer = SnowballStemmer('english', ignore_stopwords=True)
    stemmer.stopwords = all_stopwords
    
    stemmed_words = []
    
    for w in text.split():
        stemmed_words.append(stemmer.stem(w))
        
    text = ' '.join(stemmed_words)
        
    return text

# %% [markdown]
# # Access database

# %%
project_folder = os.path.expanduser(
    '/Users/faustina/METIS/BOOTCAMPWORK/Project5/controlledchaos/data/')  # the folder of your project
load_dotenv(os.path.join(project_folder, '.env'))

MONGODBNAME = os.getenv("MONGODBNAME")

client = pymongo.MongoClient()
db = client[MONGODBNAME]
curr_files_db = db['curr_files']

# %%
folder = '../data/test_case1/'
test_case = os.listdir(folder)

# %% [markdown]
# # Load files

# %%
curr_files_db.delete_many({})
curr_files_db.insert_many([get_attributes(file, folder) for file in test_case])
cursor = curr_files_db.find({})
entries = list(cursor)

# %% [markdown]
# # Categorization

# %%
files_w_attributes = entries

blind_cats = {k: list(curr_files_db.find({"extension": {"$in": v}})) for k, v in formats.items()}
blind_cats = {item: blind_cats[item] for item in sorted(blind_cats, key=lambda i: len(blind_cats[i]), reverse=True)}

# %%
def blind_categories(format_dict, collection):
    blind_classifier = {k: list(collection.find(
        {"extension": {"$in": v}})) for k, v in format_dict.items()}

    for k, v in blind_classifier.items():
        [(file.pop('_id', None) and file.pop('text', None)) for file in v]

    blind_classifier = {item: blind_classifier[item] for item in sorted(
        blind_classifier, key=lambda i: len(blind_classifier[i]), reverse=True)}
    return blind_classifier

# %% [markdown]
# # Text
#
# 1. Extraction
# 2. Preprocessing
#
#     1. Remove punctuation marks
#     2. Replace newline and tab characters with common spaces
#     3. Lemmatize
#
# 3. Stemming (Snowball)
#     1. Preserve stopwords
#     2. Stem non-stopword words
#
# 4. Build corpus with lemmatized text
# 5. Convert corpus to a matrix of TF-IDF features
#     1. Unigrams
#     2. Words with more than 3 characters
#     3. Terms present in at least 2 documents
#     4. Terms present in at most 40% of the files analyzed

# %%
text_ext = ['ppt', 'pptx', 'doc', 'docx', 'odt', 'pdf',
                'rtf', 'text', 'txt', 'wpd', 'ods']

# %%
for file in curr_files_db.find({'extension': {"$in": text_ext}}):
    file_text = extract_text(file)
    if file_text:
        curr_files_db.update_one({'_id': file['_id']}, {"$set": {"text": file_text}})

# %%
file
# Out:
# {'_id': ObjectId('5f5fa71af48baabc28c6c7ba'),
#  'parent_folder': '../data/test_case1/',
#  'absolute_path': '../data/test_case1/000464.text',
#  'name': '000464.text',
#  'size_mb': 0.094528,
#  'created_on': datetime.datetime(2011, 2, 8, 15, 38, 16),
#  'last_modified_on': datetime.datetime(2011, 2, 8, 15, 38, 16),
#  'extension': 'text',
#  'text': None}

# %%
for file in curr_files_db.find({'extension': {"$in": text_ext}}):
    curr_files_db.update_one({'_id': file['_id'], "text": {"$exists": True}}, {"$set": {"preproc_text": preprocessing(file['text'])}})

# %%
for file in curr_files_db.find({'extension': {"$in": text_ext}}):
    curr_files_db.update_one({'_id': file['_id'], "preproc_text": {"$exists": True}}, {"$set": {"lemma_text": stemming(file['preproc_text'])}})

# %%
corpus = [file['lemma_text'] for file in list(curr_files_db.find({'extension': {"$in": text_ext}}))]

# %%
params = {
        'vectorizer': {
            'analyzer': 'word',
            'stop_words': stopwords.words('english'),
            'ngram_range': (1, 2),
            'token_pattern': '[a-z]{3,}',
            'min_df': 2,
            'max_df': 10,
            'lowercase': True
        }
    }

tfidf = TfidfVectorizer(**params['vectorizer'])

# %%
X_tfidf = tfidf.fit_transform(corpus)

# %%
def labels(corpus, vectorizer=tfidf, nclusters=10):
    try:
        X = tfidf.fit_transform(corpus)
        km = KMeans(n_clusters=nclusters).fit(X)
        return km.labels_
    except:
        return 404

# %% [markdown]
# # SVD
#
# 1. Calculate matrix decomposition to get sigma values
# 2. Calculate minimum optimal k to produce clusters

# %%
k = 100
U, Sigma, VT = randomized_svd(X_tfidf.toarray(), 
                              n_components=k,
                              n_iter=5,
                              random_state=None)

# %%
opt_k = 0

for idx, sig in enumerate(Sigma):
    if (idx + 2) < len(Sigma):
        #print(sig, Sigma[idx + 1])
        if (str(sig)[:4] == str(Sigma[idx + 1])[:4] == str(Sigma[idx + 2])[:4]):
            print(sig, Sigma[idx + 1])
            print(idx)
            opt_k = idx
            break
# Out:
# 1.0388972767079476 1.0352513808115358
# 15

# %% [markdown]
# # Clustering

# %%
entries = list(curr_files_db.find({"text": {"$exists": True}}))
raw_docs = [file['text'] for file in entries]
doc_labels = labels(raw_docs, nclusters=opt_k)

# %% [markdown]
# # Update database with labels

# %%
for idx, entry in enumerate(entries):
    curr_files_db.update_one({'_id': entry['_id']}, {"$set": {"label": 'topic{}'.format(doc_labels[idx])}})

# %% [markdown]
# # Agreggation

# %%
topic_files = {}

for i in range(opt_k):
    entries = list(curr_files_db.find({"label": {"$exists": True}, "label": 'topic{}'.format(i)}))
    if len(entries):
        topic_name = name_cluster_labels_common(custom_sw, entries, words=5)
        topic_files[topic_name] = entries
    else:
        break

# %%
for k, v in topic_files.items():
    [[file.pop(file_key, None) for file_key in ['_id', 'text', 'preproc_text', 'lemma_text']] for file in v]

# %%
topic_files
# Out:
# {'DIRS-system-event-sequence-section': [{'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/000487.text',
#    'name': '000487.text',
#    'size_mb': 0.030667,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 38, 18),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 38, 18),
#    'extension': 'text',
#    'label': 'topic0'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/001751.text',
#    'name': '001751.text',
#    'size_mb': 0.061148,
#    'created_on': datetime.datetime(2009, 3, 5, 16, 29, 34),
#    'last_modified_on': datetime.datetime(2009, 3, 5, 16, 29, 34),
#    'extension': 'text',
#    'label': 'topic0'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/002087.text',
#    'name': '002087.text',
#    'size_mb': 0.230421,
#    'created_on': datetime.datetime(2009, 3, 5, 15, 59, 6),
#    'last_modified_on': datetime.datetime(2009, 3, 5, 15, 59, 6),
#    'extension': 'text',
#    'label': 'topic0'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/002603.text',
#    'name': '002603.text',
#    'size_mb': 0.375936,
#    'created_on': datetime.datetime(2009, 3, 5, 15, 58, 46),
#    'last_modified_on': datetime.datetime(2009, 3, 5, 15, 58, 46),
#    'extension': 'text',
#    'label': 'topic0'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/003371.ppt',
#    'name': '003371.ppt',
#    'size_mb': 1.293312,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 53, 10),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 53, 10),
#    'extension': 'ppt',
#    'label': 'topic0'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/003698.pdf',
#    'name': '003698.pdf',
#    'size_mb': 0.034616,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 53, 22),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 53, 22),
#    'extension': 'pdf',
#    'label': 'topic0'}],
#  'computer-Service-decision-Resources-list': [{'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/000581.pdf',
#    'name': '000581.pdf',
#    'size_mb': 0.198511,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 38, 24),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 38, 24),
#    'extension': 'pdf',
#    'label': 'topic1'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/000854.text',
#    'name': '000854.text',
#    'size_mb': 0.070109,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 38, 38),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 38, 38),
#    'extension': 'text',
#    'label': 'topic1'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/001370.pdf',
#    'name': '001370.pdf',
#    'size_mb': 2.593056,
#    'created_on': datetime.datetime(2009, 3, 5, 16, 29, 42),
#    'last_modified_on': datetime.datetime(2009, 3, 5, 16, 29, 42),
#    'extension': 'pdf',
#    'label': 'topic1'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/003623.doc',
#    'name': '003623.doc',
#    'size_mb': 0.037376,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 53, 20),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 53, 20),
#    'extension': 'doc',
#    'label': 'topic1'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/004871.ppt',
#    'name': '004871.ppt',
#    'size_mb': 0.091136,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 54, 14),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 54, 14),
#    'extension': 'ppt',
#    'label': 'topic1'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/004957.text',
#    'name': '004957.text',
#    'size_mb': 0.193604,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 54, 16),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 54, 16),
#    'extension': 'text',
#    'label': 'topic1'}],
#  'John-Washington-Joseph-Health-Brown': [{'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/000251.doc',
#    'name': '000251.doc',
#    'size_mb': 0.134656,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 38, 4),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 38, 4),
#    'extension': 'doc',
#    'label': 'topic2'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/000476.text',
#    'name': '000476.text',
#    'size_mb': 0.117844,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 38, 18),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 38, 18),
#    'extension': 'text',
#    'label': 'topic2'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/000503.text',
#    'name': '000503.text',
#    'size_mb': 0.041815,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 38, 18),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 38, 18),
#    'extension': 'text',
#    'label': 'topic2'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/002154.doc',
#    'name': '002154.doc',
#    'size_mb': 0.14592,
#    'created_on': datetime.datetime(2009, 3, 5, 15, 59, 18),
#    'last_modified_on': datetime.datetime(2009, 3, 5, 15, 59, 18),
#    'extension': 'doc',
#    'label': 'topic2'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/002928.text',
#    'name': '002928.text',
#    'size_mb': 0.198495,
#    'created_on': datetime.datetime(2009, 3, 5, 15, 59, 8),
#    'last_modified_on': datetime.datetime(2009, 3, 5, 15, 59, 8),
#    'extension': 'text',
#    'label': 'topic2'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/003017.text',
#    'name': '003017.text',
#    'size_mb': 0.16808,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 52, 58),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 52, 58),
#    'extension': 'text',
#    'label': 'topic2'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/003026.text',
#    'name': '003026.text',
#    'size_mb': 0.35904,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 52, 58),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 52, 58),
#    'extension': 'text',
#    'label': 'topic2'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/004406.text',
#    'name': '004406.text',
#    'size_mb': 0.093343,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 53, 56),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 53, 56),
#    'extension': 'text',
#    'label': 'topic2'}],
#  'plan-claim-payment-value-Americredit': [{'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/000562.pdf',
#    'name': '000562.pdf',
#    'size_mb': 0.046553,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 38, 22),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 38, 22),
#    'extension': 'pdf',
#    'label': 'topic3'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/002165.pdf',
#    'name': '002165.pdf',
#    'size_mb': 0.031842,
#    'created_on': datetime.datetime(2009, 3, 5, 15, 59, 8),
#    'last_modified_on': datetime.datetime(2009, 3, 5, 15, 59, 8),
#    'extension': 'pdf',
#    'label': 'topic3'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/004902.pdf',
#    'name': '004902.pdf',
#    'size_mb': 0.03204,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 54, 14),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 54, 14),
#    'extension': 'pdf',
#    'label': 'topic3'}],
#  'Systems-Lunar-Surface-Concepts-place': [{'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/000486.text',
#    'name': '000486.text',
#    'size_mb': 0.005029,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 38, 18),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 38, 18),
#    'extension': 'text',
#    'label': 'topic4'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/000737.pdf',
#    'name': '000737.pdf',
#    'size_mb': 3.613556,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 38, 34),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 38, 34),
#    'extension': 'pdf',
#    'label': 'topic4'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/002421.ppt',
#    'name': '002421.ppt',
#    'size_mb': 3.257344,
#    'created_on': datetime.datetime(2009, 3, 5, 15, 58, 46),
#    'last_modified_on': datetime.datetime(2009, 3, 5, 15, 58, 46),
#    'extension': 'ppt',
#    'label': 'topic4'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/002573.text',
#    'name': '002573.text',
#    'size_mb': 0.004049,
#    'created_on': datetime.datetime(2009, 3, 5, 15, 59, 6),
#    'last_modified_on': datetime.datetime(2009, 3, 5, 15, 59, 6),
#    'extension': 'text',
#    'label': 'topic4'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/003837.pdf',
#    'name': '003837.pdf',
#    'size_mb': 2.335987,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 53, 28),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 53, 28),
#    'extension': 'pdf',
#    'label': 'topic4'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/004775.text',
#    'name': '004775.text',
#    'size_mb': 0.005375,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 54, 10),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 54, 10),
#    'extension': 'text',
#    'label': 'topic4'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/004799.text',
#    'name': '004799.text',
#    'size_mb': 0.026324,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 54, 10),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 54, 10),
#    'extension': 'text',
#    'label': 'topic4'}],
#  'theory-polarization-physical-evolve-Standard': [{'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/002186.pdf',
#    'name': '002186.pdf',
#    'size_mb': 1.541152,
#    'created_on': datetime.datetime(2009, 3, 5, 15, 59, 20),
#    'last_modified_on': datetime.datetime(2009, 3, 5, 15, 59, 20),
#    'extension': 'pdf',
#    'label': 'topic5'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/002206.pdf',
#    'name': '002206.pdf',
#    'size_mb': 0.07467,
#    'created_on': datetime.datetime(2009, 3, 5, 15, 58, 56),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 12, 28, 33),
#    'extension': 'pdf',
#    'label': 'topic5'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/002313.ppt',
#    'name': '002313.ppt',
#    'size_mb': 0.549376,
#    'created_on': datetime.datetime(2009, 3, 5, 15, 58, 50),
#    'last_modified_on': datetime.datetime(2009, 3, 5, 15, 58, 50),
#    'extension': 'ppt',
#    'label': 'topic5'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/002595.text',
#    'name': '002595.text',
#    'size_mb': 0.02526,
#    'created_on': datetime.datetime(2009, 3, 5, 15, 58, 58),
#    'last_modified_on': datetime.datetime(2009, 3, 5, 15, 58, 58),
#    'extension': 'text',
#    'label': 'topic5'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/004043.doc',
#    'name': '004043.doc',
#    'size_mb': 0.449024,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 53, 46),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 53, 46),
#    'extension': 'doc',
#    'label': 'topic5'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/004629.ppt',
#    'name': '004629.ppt',
#    'size_mb': 0.103936,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 54, 4),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 54, 4),
#    'extension': 'ppt',
#    'label': 'topic5'}],
#  'libcr-Wall-source-include-protector': [{'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/000295.ppt',
#    'name': '000295.ppt',
#    'size_mb': 0.367616,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 38, 6),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 38, 6),
#    'extension': 'ppt',
#    'label': 'topic6'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/001185.text',
#    'name': '001185.text',
#    'size_mb': 0.012283,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 38, 58),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 38, 58),
#    'extension': 'text',
#    'label': 'topic6'}],
#  'MIAMI-NORTH-DIXIE-SUITE-HAAT': [{'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/002863.pdf',
#    'name': '002863.pdf',
#    'size_mb': 0.13894,
#    'created_on': datetime.datetime(2009, 3, 5, 15, 59, 8),
#    'last_modified_on': datetime.datetime(2009, 3, 5, 15, 59, 8),
#    'extension': 'pdf',
#    'label': 'topic7'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/002989.pdf',
#    'name': '002989.pdf',
#    'size_mb': 0.268268,
#    'created_on': datetime.datetime(2009, 3, 5, 15, 59, 18),
#    'last_modified_on': datetime.datetime(2009, 3, 5, 15, 59, 18),
#    'extension': 'pdf',
#    'label': 'topic7'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/003143.text',
#    'name': '003143.text',
#    'size_mb': 0.287771,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 53, 2),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 53, 2),
#    'extension': 'text',
#    'label': 'topic7'}],
#  'program-housing-home-Plan-need': [{'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/000728.ppt',
#    'name': '000728.ppt',
#    'size_mb': 0.403456,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 38, 32),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 38, 32),
#    'extension': 'ppt',
#    'label': 'topic8'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/002403.doc',
#    'name': '002403.doc',
#    'size_mb': 0.340992,
#    'created_on': datetime.datetime(2009, 3, 5, 15, 58, 48),
#    'last_modified_on': datetime.datetime(2009, 3, 5, 15, 58, 48),
#    'extension': 'doc',
#    'label': 'topic8'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/002448.ppt',
#    'name': '002448.ppt',
#    'size_mb': 0.211456,
#    'created_on': datetime.datetime(2009, 3, 5, 15, 58, 40),
#    'last_modified_on': datetime.datetime(2009, 3, 5, 15, 58, 40),
#    'extension': 'ppt',
#    'label': 'topic8'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/004255.text',
#    'name': '004255.text',
#    'size_mb': 8.156676,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 53, 52),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 53, 52),
#    'extension': 'text',
#    'label': 'topic8'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/004955.text',
#    'name': '004955.text',
#    'size_mb': 0.013413,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 54, 16),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 54, 16),
#    'extension': 'text',
#    'label': 'topic8'}],
#  'subclass-class-system-material-liquid': [{'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/002683.doc',
#    'name': '002683.doc',
#    'size_mb': 0.536064,
#    'created_on': datetime.datetime(2009, 3, 5, 15, 59, 16),
#    'last_modified_on': datetime.datetime(2009, 3, 5, 15, 59, 16),
#    'extension': 'doc',
#    'label': 'topic9'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/002735.pdf',
#    'name': '002735.pdf',
#    'size_mb': 1.423806,
#    'created_on': datetime.datetime(2009, 3, 5, 15, 59, 6),
#    'last_modified_on': datetime.datetime(2009, 3, 5, 15, 59, 6),
#    'extension': 'pdf',
#    'label': 'topic9'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/002796.text',
#    'name': '002796.text',
#    'size_mb': 0.03413,
#    'created_on': datetime.datetime(2009, 3, 5, 15, 59, 18),
#    'last_modified_on': datetime.datetime(2009, 3, 5, 15, 59, 18),
#    'extension': 'text',
#    'label': 'topic9'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/002979.pdf',
#    'name': '002979.pdf',
#    'size_mb': 0.297794,
#    'created_on': datetime.datetime(2009, 3, 5, 15, 59, 16),
#    'last_modified_on': datetime.datetime(2009, 3, 5, 15, 59, 16),
#    'extension': 'pdf',
#    'label': 'topic9'}],
#  'plant-shoot-water-deficient-vaccine': [{'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/001756.text',
#    'name': '001756.text',
#    'size_mb': 0.03279,
#    'created_on': datetime.datetime(2009, 3, 5, 16, 29, 6),
#    'last_modified_on': datetime.datetime(2009, 3, 5, 16, 29, 6),
#    'extension': 'text',
#    'label': 'topic10'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/002489.pdf',
#    'name': '002489.pdf',
#    'size_mb': 0.641106,
#    'created_on': datetime.datetime(2009, 3, 5, 15, 58, 42),
#    'last_modified_on': datetime.datetime(2009, 3, 5, 15, 58, 42),
#    'extension': 'pdf',
#    'label': 'topic10'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/002670.doc',
#    'name': '002670.doc',
#    'size_mb': 0.155648,
#    'created_on': datetime.datetime(2009, 3, 5, 15, 59, 2),
#    'last_modified_on': datetime.datetime(2009, 3, 5, 15, 59, 2),
#    'extension': 'doc',
#    'label': 'topic10'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/003410.pdf',
#    'name': '003410.pdf',
#    'size_mb': 0.306965,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 53, 12),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 53, 12),
#    'extension': 'pdf',
#    'label': 'topic10'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/003439.pdf',
#    'name': '003439.pdf',
#    'size_mb': 0.070311,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 53, 14),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 53, 14),
#    'extension': 'pdf',
#    'label': 'topic10'}],
#  'time-common-number-step-true': [{'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/003009.text',
#    'name': '003009.text',
#    'size_mb': 0.009456,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 52, 56),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 52, 56),
#    'extension': 'text',
#    'label': 'topic11'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/003767.text',
#    'name': '003767.text',
#    'size_mb': 0.055569,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 53, 24),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 53, 24),
#    'extension': 'text',
#    'label': 'topic11'}],
#  'name-generic-agent-term-establish': [{'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/000945.doc',
#    'name': '000945.doc',
#    'size_mb': 0.075776,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 38, 44),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 38, 44),
#    'extension': 'doc',
#    'label': 'topic12'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/001851.doc',
#    'name': '001851.doc',
#    'size_mb': 0.10752,
#    'created_on': datetime.datetime(2009, 3, 5, 16, 29, 36),
#    'last_modified_on': datetime.datetime(2009, 3, 5, 16, 29, 36),
#    'extension': 'doc',
#    'label': 'topic12'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/002407.doc',
#    'name': '002407.doc',
#    'size_mb': 0.591872,
#    'created_on': datetime.datetime(2009, 3, 5, 15, 58, 50),
#    'last_modified_on': datetime.datetime(2009, 3, 5, 15, 58, 50),
#    'extension': 'doc',
#    'label': 'topic12'}],
#  'AMSU-FELIX-Atlantic-http-noaa': [{'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/000459.text',
#    'name': '000459.text',
#    'size_mb': 0.023782,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 38, 16),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 38, 16),
#    'extension': 'text',
#    'label': 'topic13'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/000464.text',
#    'name': '000464.text',
#    'size_mb': 0.094528,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 38, 16),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 38, 16),
#    'extension': 'text',
#    'label': 'topic13'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/002718.pdf',
#    'name': '002718.pdf',
#    'size_mb': 0.057074,
#    'created_on': datetime.datetime(2009, 3, 5, 15, 59, 20),
#    'last_modified_on': datetime.datetime(2009, 3, 5, 15, 59, 20),
#    'extension': 'pdf',
#    'label': 'topic13'}],
#  'grid-Contact-Domain-source-Value': [{'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/000167.pdf',
#    'name': '000167.pdf',
#    'size_mb': 0.643818,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 38),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 18, 13),
#    'extension': 'pdf',
#    'label': 'topic14'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/000222.text',
#    'name': '000222.text',
#    'size_mb': 0.032035,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 38, 2),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 38, 2),
#    'extension': 'text',
#    'label': 'topic14'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/000835.text',
#    'name': '000835.text',
#    'size_mb': 0.021301,
#    'created_on': datetime.datetime(2011, 2, 8, 15, 38, 38),
#    'last_modified_on': datetime.datetime(2011, 2, 8, 15, 38, 38),
#    'extension': 'text',
#    'label': 'topic14'},
#   {'parent_folder': '../data/test_case1/',
#    'absolute_path': '../data/test_case1/001588.text',
#    'name': '001588.text',
#    'size_mb': 0.05073,
#    'created_on': datetime.datetime(2009, 3, 5, 16, 29, 24),
#    'last_modified_on': datetime.datetime(2009, 3, 5, 16, 29, 24),
#    'extension': 'text',
#    'label': 'topic14'}]}

# %%
pickle.dump(topic_files, open('../app/data/test1.pkl', 'wb'))

# %% [raw]
# cursor = curr_files_db.find({})
# entries = list(cursor)
#
# text_files = [
#     file for file in entries if file['extension'] in formats['text']]
#
# raw_docs = [extract_text(file) for file in text_files]
#
# doc_labels = labels(raw_docs)
# if doc_labels == 404:
#     return redirect(url_for('index'))
# else:
#     for idx, file in enumerate(text_files):
#         text_files[idx]['topic'] = doc_labels[idx]
#
#     topic_files = get_topic_files(text_files)
#     topic_names = name_cluster_labels_common(
#         custom_sw, topic_files, words=8)
