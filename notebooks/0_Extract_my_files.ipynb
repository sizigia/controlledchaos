# %%
import folderstats
import os

# %%
os.chdir('/Users/faustina/Documents/Instagram/')
os.getcwd()
# Out:
# '/Users/faustina/Documents/Instagram'

# %%
docs_folder = folderstats.folderstats(os.getcwd())

# %%
docs_folder.to_csv('personal_data.csv', index=False)

# %%
files = docs_folder[~docs_folder.folder]
files
# Out:
#           id                                               path  \
# 0          2      /Users/faustina/Documents/Instagram/.DS_Store
# 1          4  /Users/faustina/Documents/Instagram/.vscode/se...
# 4          7  /Users/faustina/Documents/Instagram/beautyfrea...
# 5          8  /Users/faustina/Documents/Instagram/beautyfrea...
# 6          9  /Users/faustina/Documents/Instagram/beautyfrea...
# ...      ...                                                ...
# 29306  29309  /Users/faustina/Documents/Instagram/themindgee...
# 29307  29310  /Users/faustina/Documents/Instagram/themindgee...
# 29308  29311  /Users/faustina/Documents/Instagram/themindgee...
# 29309  29312  /Users/faustina/Documents/Instagram/themindgee...
# 29310  29313  /Users/faustina/Documents/Instagram/themindgee...
#
#                                                   name extension    size  \
# 0                                            .DS_Store      None   10244
# ...

# %%
docs_folder.num_files.unique()
docs_folder.extension.unique()
# Out:
# array([None, 'json', 'jpg', 'txt', 'mp4', 'room_id', 'revolucionario_id',
#        'py', 'sh', 'psychologist_id'], dtype=object)

# %%
files.extension.unique()
# Out:
# array([None, 'pdf', 'mp3', 'MP3', 'png', 'json', 'jpg', 'txt', 'mp4',
#        'room_id', 'revolucionario_id', 'py', 'sh', 'psychologist_id',
#        'm4a', 'webp', 'xspf', 'db', 'url', 'jpeg', 'PNG', 'JPG', 'ini',
#        'wma', 'Mp3', 'itlp', 'js', 'css', 'html', 'plist', 'xml', 'aif',
#        'm3u', 'URL', 'mpeg', 'tds', 'xls', 'hyper', 'log', 'marker',
#        'tps', 'ipynb', 'zip', 'pptx', 'ttf'], dtype=object)

# %%
files[files.extension == 'xspf']
# Out:
#           id                                               path  \
# 29776  29779  /Users/faustina/Documents/Music/Mi música (Wi...
# 33022  33025  /Users/faustina/Documents/Music/PostMalone.mp4...
# 33023  33026    /Users/faustina/Documents/Music/PostMalone.xspf
#
#                     name extension   size               atime  \
# 29776  Mi música (Wind)      xspf  12944 2020-07-21 22:56:53
# 33022     PostMalone.mp4      xspf  36904 2020-07-21 22:57:00
# 33023         PostMalone      xspf  23668 2020-07-21 22:57:00
#
#                     mtime               ctime  folder  num_files  depth  \
# 29776 2019-02-20 07:39:06 2020-04-29 15:02:24   False        NaN      1
# 33022 2019-05-13 10:52:38 2020-04-29 15:47:52   False        NaN      1
# 33023 2019-05-13 14:18:16 2020-04-29 15:47:52   False        NaN      1
#
#        parent  uid
# 29776   29518  501
# 33022   29518  501
# 33023   29518  501
