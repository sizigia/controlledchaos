# %% [raw]
# !pip install python-docx
# !pip install textract
# !pip install folderstats
#
# !folderstats t5/ -p -i -v -o test.csv

# %%
import os
import re
import time
import folderstats
import chardet
#import docx
import textract
import pandas as pd
from bs4 import BeautifulSoup

# %%
data_folder = os.listdir('../data/t5')

# %%
files = {}

for ext in {re.search('(\.\w+)', file).group(0) for file in data_folder if (file != '.DS_Store')}:
    filenames = [f for f in data_folder if f.endswith(ext)]
    files[ext] = {
        'count': len(filenames),
        'filenames': filenames
    }

# %%
[(key, files[key]['count']) for key in files.keys()]
# Out:
# [('.pdf', 1073),
#  ('.xls', 250),
#  ('.text', 711),
#  ('.doc', 533),
#  ('.html', 1093),
#  ('.jpg', 362),
#  ('.gif', 67),
#  ('.ppt', 368)]

# %%
files.keys()
# Out:
# dict_keys(['.pdf', '.xls', '.text', '.doc', '.html', '.jpg', '.gif', '.ppt'])

# %%
files['.pdf', '.xls', ]

# %%
with open('../data/t5/000077.html', 'r') as file:
    test_html = file.readlines()

# %%
# Out:
# '<html>\n <head>\n <title>1997 Economic Census:  ZIP Code Statistics\n  - 98589\n </title>\n </head>\n \n <body bgcolor=#ffffff vlink=#66330>\n <a href="http://www.census.gov">\n <img src="http://www.census.gov/main/www/img/cb_head.gif" border="0" alt="U.S. Census Bureau"></a>\n <table width="100%"><tr><td rowspan="3" align="left">\n <a href="/epcd/www/econ97.html"><img src="../../www/img/ec97_76.gif" border="0" alt="1997 Economic Census main page"></a></td>\n <td rowspan="3"><b><font size="+2">1997 Economic Census: \n <br>  ZIP Code Statistics\n <br>98589\n &nbsp; </font> &nbsp;   (Tenino, WA)\n </b></td>\n \n <td align="right" valign="bottom">  <FONT FACE="Arial, Helvetica"><font size=2>\n <FORM ACTION="http://www.census.gov/cgi-bin/geo/location" METHOD="POST">\n <select name="Location">\n  <option value="/epcd/ec97zip/us/US000.HTM">Select a state\n </option> \n <option value="/epcd/ec97zip/us/US00000.HTM">\n United States</option> <option value="/epcd/ec97zip/al/AL00000.HTM">\n Alabama</option> <option value="/epcd/ec97zip/ak/AK00000.HTM">\n Alaska</option> <option value="/epcd/ec97zip/az/AZ00000.HTM">\n Arizona</option> <option value="/epcd/ec97zip/ar/AR00000.HTM">\n Arkansas</option> <option value="/epcd/ec97zip/ca/CA00000.HTM">\n California</option> <option value="/epcd/ec97zip/co/CO00000.HTM">\n Colorado</option> <option value="/epcd/ec97zip/ct/CT00000.HTM">\n Connecticut</option> <option value="/epcd/ec97zip/de/DE00000.HTM">\n Delaware</option> <option value="/epcd/ec97zip/dc/DC00000.HTM">\n District of Columbia</option> <option value="/epcd/ec97zip/fl/FL00000.HTM">\n Florida</option> <option value="/epcd/ec97zip/ga/GA00000.HTM">\n Georgia</option> <option value="/epcd/ec97zip/hi/HI00000.HTM">\n Hawaii</option> <option value="/epcd/ec97zip/id/ID00000.HTM">\n Idaho</option> <option value="/epcd/ec97zip/il/IL00000.HTM">\n Illinois</option> <option value="/epcd/ec97zip/in/IN00000.HTM">\n Indiana</option> <option value="/epcd/ec97zip/ia/IA00000.HTM">\n Iowa</option> <option value="/epcd/ec97zip/ks/KS00000.HTM">\n Kansas</option> <option value="/epcd/ec97zip/ky/KY00000.HTM">\n Kentucky</option> <option value="/epcd/ec97zip/la/LA00000.HTM">\n Louisiana</option> <option value="/epcd/ec97zip/me/ME00000.HTM">\n Maine</option> <option value="/epcd/ec97zip/md/MD00000.HTM">\n Maryland</option> <option value="/epcd/ec97zip/ma/MA00000.HTM">\n Massachusetts</option> <option value="/epcd/ec97zip/mi/MI00000.HTM">\n Michigan</option> <option value="/epcd/ec97zip/mn/MN00000.HTM">\n Minnesota</option> <option value="/epcd/ec97zip/ms/MS00000.HTM">\n Mississippi</option> <option value="/epcd/ec97zip/mo/MO00000.HTM">\n Missouri</option> <option value="/epcd/ec97zip/mt/MT00000.HTM">\n Montana</option> <option value="/epcd/ec97zip/ne/NE00000.HTM">\n Nebraska</option> <option value="/epcd/ec97zip/nv/NV00000.HTM">\n Nevada</option> <option value="/epcd/ec97zip/nh/NH00000.HTM">\n New Hampshire</option> <option value="/epcd/ec97zip/nj/NJ00000.HTM">\n New Jersey</option> <option value="/epcd/ec97zip/nm/NM00000.HTM">\n New Mexico</option> <option value="/epcd/ec97zip/ny/NY00000.HTM">\n New York</option> <option value="/epcd/ec97zip/nc/NC00000.HTM">\n North Carolina</option> <option value="/epcd/ec97zip/nd/ND00000.HTM">\n North Dakota</option> <option value="/epcd/ec97zip/oh/OH00000.HTM">\n Ohio</option> <option value="/epcd/ec97zip/ok/OK00000.HTM">\n Oklahoma</option> <option value="/epcd/ec97zip/or/OR00000.HTM">\n Oregon</option> <option value="/epcd/ec97zip/pa/PA00000.HTM">\n Pennsylvania</option> <option value="/epcd/ec97zip/ri/RI00000.HTM">\n Rhode Island</option> <option value="/epcd/ec97zip/sc/SC00000.HTM">\n South Carolina</option> <option value="/epcd/ec97zip/sd/SD00000.HTM">\n South Dakota</option> <option value="/epcd/ec97zip/tn/TN00000.HTM">\n Tennessee</option> <option value="/epcd/ec97zip/tx/TX00000.HTM">\n Texas</option> <option value="/epcd/ec97zip/us/US00000.HTM">\n United States</option> <option value="/epcd/ec97zip/ut/UT00000.HTM"> ...

# %%
soup = BeautifulSoup(' '.join(test_html), 'html.parser')

# %%
soup.find('body').text
# Out:
# '\n\n\n\n\n1997 Economic Census: \n   ZIP Code Statistics\n 98589\n \xa0  \xa0   (Tenino, WA)\n \n \n\n\nSelect a state\n \n\n United States \n Alabama \n Alaska \n Arizona \n Arkansas \n California \n Colorado \n Connecticut \n Delaware \n District of Columbia \n Florida \n Georgia \n Hawaii \n Idaho \n Illinois \n Indiana \n Iowa \n Kansas \n Kentucky \n Louisiana \n Maine \n Maryland \n Massachusetts \n Michigan \n Minnesota \n Mississippi \n Missouri \n Montana \n Nebraska \n Nevada \n New Hampshire \n New Jersey \n New Mexico \n New York \n North Carolina \n North Dakota \n Ohio \n Oklahoma \n Oregon \n Pennsylvania \n Rhode Island \n South Carolina \n South Dakota \n Tennessee \n Texas \n United States \n Utah \n Vermont \n Virginia \n Washington \n West Virginia \n Wisconsin \n Wyoming\n\n\n\n\n \n\n\nSelect 1st 3 digits of ZIP in WA\n \n980\n981\n982\n983\n984\n985\n986\n988\n989\n990\n991\n992\n993\n994\n999\n\n\n\n\n'

# %% [raw]
# os.stat('t5/000015.pdf')

# %% [raw]
# time.ctime(os.stat('t5/000015.pdf').st_birthtime)

# %% [raw]
# os.stat('t5/000015.pdf')

# %% [raw]
# info = {}
# attrs = ['st_mode',
# 'st_ino',
# 'st_dev',
# 'st_nlink',
# 'st_uid',
# 'st_gid',
# 'st_size',
# 'st_atime',
# 'st_mtime',
# 'st_ctime']
#
#
# list(zip(attrs, os.stat('t5/000015.pdf')))

# %% [raw]
# import linecache
#
# linecache.getline('t5/000044.xls', 15)

# %% [raw]
# with open('t5/003520.text', 'rb') as file:
#     print(file.readline())

# %% [raw]
# time.ctime(os.path.getatime('t5/003520.text'))

# %%
df = folderstats.folderstats('t5/', ignore_hidden=True)
df.head()
# Out:
#    id           path    name extension    size               atime  \
# 0   2  t5/000001.doc  000001       doc       0 2020-09-02 12:08:42
# 1   3  t5/000002.doc  000002       doc   57856 2020-08-27 22:13:50
# 2   4  t5/000003.doc  000003       doc   55808 2020-09-02 10:27:33
# 3   5  t5/000004.doc  000004       doc  175616 2020-08-27 22:13:50
# 4   6  t5/000005.doc  000005       doc  180736 2020-08-27 22:13:50
#
#                 mtime               ctime  folder  num_files  depth  parent  \
# 0 2020-09-02 12:08:29 2020-09-02 12:08:29   False        NaN      0       1
# 1 2011-02-08 15:37:40 2020-08-27 22:13:40   False        NaN      0       1
# 2 2011-02-08 15:37:40 2020-08-27 22:13:40   False        NaN      0       1
# 3 2011-02-08 15:37:40 2020-08-27 22:13:40   False        NaN      0       1
# 4 2011-02-08 15:37:40 2020-08-27 22:13:40   False        NaN      0       1
#
#    uid
# 0  501
# 1  501
# 2  501
# 3  501
# 4  501

# %%
df.shape
# Out:
# (4458, 13)

# %% [raw]
# rawdata = open('t5/002407.doc', 'rb').read()
# result = chardet.detect(rawdata)
# charenc = result['encoding']

# %%
for _ in os.listdir('t5/')[1:10]:
    print(_)
    try:
        print(textract.process('t5/' + _)[:200])
    except:
        print('')
# Out:
# 000001.doc
#
# 000002.doc
# b'\n[pic]\n\nRelease No. 0043.04\nOffice of Communications (202) 720-4623\n\n                                 BSE Update \xe2\x80\x94 January 27, 2004\n\n\n\n\nDepopulation Activities\n\n     On Monday, Jan. 26, 2004, 18 ani'
# 000003.doc
# b'\n                                    [pic]\n\nRelease No. 0048.04\nOffice of Communications (202) 720-4623\n\n                                 BSE Update \xe2\x80\x93 Wednesday, January 28, 2004\n\nDepopulation Activ'
# 000004.doc
# b'\n\n|Cascade bilberry                 |\n|Vaccinium deliciosum Piper       |\n|Plant Symbol = VADE              |\n\nContributed by: USDA NRCS National Plant Data Center & Oregon Plant\nMaterials Center\n\n\n\n\n'
# 000005.doc
# b'\n\n|black huckleberry                |\n|Vaccinium membranaceum Dougl. ex |\n|Torr.                            |\n|Plant Symbol = VAME              |\n\nContributed by: USDA NRCS National Plant Data Center '
# 000006.doc
# b'\nBefore the\n                      Federal Communications Commission\n                           Washington, D.C. 20554\n\n\n|In the Matter of                    |)   |                                |\n|  '
# 000007.doc
# b'\n\n\n\n                                 APPENDIX D\n\n\n                 RACE AND NATIONALITY DESCRIPTIONS FROM THE\n                 2000 CENSUS AND BUREAU OF VITAL STATISTICS\n                              '
# 000008.ppt
#
# 000009.pdf
# b'Table DP-1. Profile of General Demographic Characteristics: 2000\nGeographic area: Tenino city, Washington\n[For information on confidentiality protection, nonsampling error, and definitions, see text]\n'

# %%
def extract_text_from_df(file):
    text = None
    
    if not file['folder']:
        try:
            text = textract.process(file['path'])
        except:
            pass
        
    return text

# %%
df['raw_text'] = df.apply(lambda file: extract_text_from_df(file), axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ae34221b765c> in <module>
# ----> 1 df['raw_text'] = df.apply(lambda file: extract_text_from_df(file), axis=1)
#
# NameError: name 'df' is not defined
