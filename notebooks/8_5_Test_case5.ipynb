# %%
def get_attributes(filepath, folder):
    if not folder.endswith('/'):
        folder = folder + '/'

    file = folder + filepath
    file_stats = os.stat(file)
    attributes = {'parent_folder': folder,
                  'absolute_path': file,
                  'name': filepath,
                  'size_mb': file_stats.st_size / 1e+6,
                  'created_on': datetime.fromtimestamp(file_stats.st_birthtime),
                  'last_modified_on': datetime.fromtimestamp(file_stats.st_mtime)}

    if os.path.isdir(file):
        ext = 'folder'
    elif os.path.isfile(file):
        ext = filepath.split('.')[-1]
    else:
        ext = ''

    attributes['extension'] = ext

    return attributes


def blind_categories(format_dict, files):
    blind_classifier = {}

    for k, v in format_dict.items():
        blind_classifier[k] = [e for e in files if (e['extension'] in v)]

    blind_classifier['folders'] = [
        e for e in files if (e['extension'] == 'folder')]
    return blind_classifier


def extract_text(record, thresh=10000):
    text_ext = ['ppt', 'pptx', 'doc', 'docx', 'odt', 'pdf',
                'rtf', 'text', 'txt', 'wpd', 'ods', 'xls', 'xlsm', 'xlsx']

    if record['extension'] in text_ext:
        text = parser.from_file(record['absolute_path'], service='text')[
            'content'][:thresh]

    return text


def labels(corpus, nclusters=10):
    params = {
        'vectorizer': {
            'analyzer': 'word',
            'stop_words': stopwords.words('english'),
            'ngram_range': (1, 1),
            'token_pattern': '[a-z]{3,}',
            'max_df': 0.1,
            'lowercase': True
        },
        'km_params': {
            'random_state': 30,
            'n_clusters': nclusters,
        }
    }

    tfidf = TfidfVectorizer(**params['vectorizer'])
    try:
        X = tfidf.fit_transform(corpus)
        km = KMeans(**params['km_params']).fit(X)
        return km.labels_
    except:
        return 404


def name_cluster_labels_common(sw, topic_files, words=8):

    label_text = ' '.join([file['preproc_text'] for file in topic_files])
    corpus = re.findall('[a-zA-Z]{4,}', label_text)
    corpus = [w for w in corpus if (w.lower() not in sw)]
    label_dict = Counter(corpus)
    cluster_name = '-'.join([w[0] for w in label_dict.most_common(words)])

    return cluster_name


def get_topic_files(files):
    topic_files = defaultdict(list)

    for file in files:
        topic_files[file['topic']].append(file)

    topic_files = dict(topic_files)

    return topic_files



def preprocessing(text):
    text = text.replace('\n', ' ')
    text = re.sub('[#]\w+', ' ', text)
    for p in punctuation:
        text = text.replace(p, ' ')
    
    sent = []
    doc = nlp(text)
    
    for word in doc:
        sent.append(word.lemma_)
    
    return " ".join(sent).replace('-PRON-', '')


def stemming(text, all_stopwords=custom_sw):
    stemmer = SnowballStemmer('english', ignore_stopwords=True)
    stemmer.stopwords = all_stopwords
    
    stemmed_words = []
    
    for w in text.split():
        stemmed_words.append(stemmer.stem(w))
        
    text = ' '.join(stemmed_words)
        
    return text

# %%
from nltk.stem import SnowballStemmer
import spacy
import string
import re
from tika import parser
import os
import re
from datetime import datetime
from bs4 import BeautifulSoup
import chardet
import textract
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from collections import Counter, defaultdict
from sklearn.utils.extmath import randomized_svd
import pickle
import os
import pymongo
from dotenv import load_dotenv
from datetime import datetime

nlp = spacy.load('en_core_web_lg')
punctuation = '!"$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'
custom_sw = pickle.load(open('../app/data/stopwords.pkl', 'rb'))
custom_sw.extend(['want'])
formats = pickle.load(open('../app/data/formats.pkl', 'rb'))

# %% [markdown]
# # Access database

# %%
project_folder = os.path.expanduser(
    '/Users/faustina/METIS/BOOTCAMPWORK/Project5/controlledchaos/data/')  # the folder of your project
load_dotenv(os.path.join(project_folder, '.env'))

MONGODBNAME = os.getenv("MONGODBNAME")

client = pymongo.MongoClient()
db = client[MONGODBNAME]
curr_files_db = db['curr_files']

# %%
folder = '../data/test_case5/'
test_case = os.listdir(folder)

# %% [markdown]
# # Load files

# %%
curr_files_db.delete_many({})
curr_files_db.insert_many([get_attributes(file, folder) for file in test_case])
cursor = curr_files_db.find({})
entries = list(cursor)

# %% [markdown]
# # Categorization

# %%
files_w_attributes = entries

blind_cats = {k: list(curr_files_db.find({"extension": {"$in": v}})) for k, v in formats.items()}
blind_cats = {item: blind_cats[item] for item in sorted(blind_cats, key=lambda i: len(blind_cats[i]), reverse=True)}

# %%
def blind_categories(format_dict, collection):
    blind_classifier = {k: list(collection.find(
        {"extension": {"$in": v}})) for k, v in format_dict.items()}

    for k, v in blind_classifier.items():
        [(file.pop('_id', None) and file.pop('text', None)) for file in v]

    blind_classifier = {item: blind_classifier[item] for item in sorted(
        blind_classifier, key=lambda i: len(blind_classifier[i]), reverse=True)}
    return blind_classifier

# %% [markdown]
# # Text
#
# 1. Extraction
# 2. Preprocessing
#
#     1. Remove punctuation marks
#     2. Replace newline and tab characters with common spaces
#     3. Lemmatize
#
# 3. Stemming (Snowball)
#     1. Preserve stopwords
#     2. Stem non-stopword words
#
# 4. Build corpus with lemmatized text
# 5. Convert corpus to a matrix of TF-IDF features
#     1. Unigrams
#     2. Words with more than 3 characters
#     3. Terms with frequencies of 1% to 20%

# %%
for file in curr_files_db.find({'extension': {"$in": formats['text']}}):
    curr_files_db.update_one({'_id': file['_id']}, {"$set": {"text": extract_text(file)}})

# %%
for file in curr_files_db.find({'extension': {"$in": formats['text']}}):
    curr_files_db.update_one({'_id': file['_id'], "text": {"$exists": True}}, {"$set": {"preproc_text": preprocessing(file['text'])}})

# %%
for file in curr_files_db.find({'extension': {"$in": formats['text']}}):
    curr_files_db.update_one({'_id': file['_id'], "preproc_text": {"$exists": True}}, {"$set": {"lemma_text": stemming(file['preproc_text'])}})

# %%
corpus = [file['lemma_text'] for file in list(curr_files_db.find({'extension': {"$in": formats['text']}}))]

# %%
params = {
        'vectorizer': {
            'analyzer': 'word',
            'stop_words': stopwords.words('english'),
            'ngram_range': (1, 1),
            'token_pattern': '[a-z]{3,}',
            'min_df': 0.01,
            'max_df': 0.2,
            'lowercase': True
        }
    }

tfidf = TfidfVectorizer(**params['vectorizer'])

# %%
X_tfidf = tfidf.fit_transform(corpus)

# %% [markdown]
# # SVD
#
# 1. Calculate matrix decomposition to get sigma values
# 2. Calculate minimum optimal k to produce clusters

# %%
k = 100
U, Sigma, VT = randomized_svd(X_tfidf.toarray(), 
                              n_components=k,
                              n_iter=5,
                              random_state=None)

# %%
opt_k = 0

for idx, sig in enumerate(Sigma):
    if (idx + 1) < len(Sigma):
        if (str(sig)[:4] == str(Sigma[idx + 1])[:4]):
            print(str(sig)[:5], str(Sigma[idx + 1])[:5])
            print(idx)
            opt_k = idx
            break
# Out:
# 1.966 1.963
# 39

# %% [markdown]
# # Clustering

# %%
entries = list(curr_files_db.find({"text": {"$exists": True}}))
raw_docs = [file['text'] for file in entries]
doc_labels = labels(raw_docs, nclusters=opt_k)

# %% [markdown]
# # Update database with labels

# %%
for idx, entry in enumerate(entries):
    curr_files_db.update_one({'_id': entry['_id']}, {"$set": {"label": 'topic{}'.format(doc_labels[idx])}})

# %% [markdown]
# # Agreggation

# %%
topic_files = {}

for i in range(20):
    entries = list(curr_files_db.find({"label": {"$exists": True}, "label": 'topic{}'.format(i)}))
    if len(entries):
        topic_name = name_cluster_labels_common(custom_sw, entries, words=5)
        topic_files[topic_name] = entries
    else:
        break

# %%
for k, v in topic_files.items():
    [[file.pop(file_key, None) for file_key in ['_id', 'text', 'preproc_text', 'lemma_text']] for file in v]

# %%
topic_files
# Out:
# {'boundary-need-feel-child-self': [{'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-05-30_13-22-20_UTC.txt',
#    'name': '2019-05-30_13-22-20_UTC.txt',
#    'size_mb': 0.001154,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'extension': 'txt',
#    'label': 'topic0'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-10-08_15-29-25_UTC.txt',
#    'name': '2019-10-08_15-29-25_UTC.txt',
#    'size_mb': 0.001014,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic0'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-10-25_16-35-49_UTC.txt',
#    'name': '2019-10-25_16-35-49_UTC.txt',
#    'size_mb': 0.001608,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic0'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-11-12_20-42-15_UTC.txt',
#    'name': '2019-11-12_20-42-15_UTC.txt',
#    'size_mb': 0.001381,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic0'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-11-15_15-35-43_UTC.txt',
#    'name': '2019-11-15_15-35-43_UTC.txt',
#    'size_mb': 0.001428,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic0'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-11-20_00-54-16_UTC.txt',
#    'name': '2019-11-20_00-54-16_UTC.txt',
#    'size_mb': 0.000451,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic0'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-12-09_00-28-55_UTC.txt',
#    'name': '2019-12-09_00-28-55_UTC.txt',
#    'size_mb': 6.6e-05,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic0'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-12-11_00-02-59_UTC.txt',
#    'name': '2019-12-11_00-02-59_UTC.txt',
#    'size_mb': 0.001248,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic0'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-01-25_23-28-22_UTC.txt',
#    'name': '2020-01-25_23-28-22_UTC.txt',
#    'size_mb': 4.9e-05,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic0'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-01-26_20-31-05_UTC.txt',
#    'name': '2020-01-26_20-31-05_UTC.txt',
#    'size_mb': 0.001395,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic0'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-02-13_05-27-57_UTC.txt',
#    'name': '2020-02-13_05-27-57_UTC.txt',
#    'size_mb': 0.000203,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic0'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-02-16_18-26-26_UTC.txt',
#    'name': '2020-02-16_18-26-26_UTC.txt',
#    'size_mb': 0.001688,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic0'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-03-01_16-02-57_UTC.txt',
#    'name': '2020-03-01_16-02-57_UTC.txt',
#    'size_mb': 0.001334,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic0'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-03-06_16-17-46_UTC.txt',
#    'name': '2020-03-06_16-17-46_UTC.txt',
#    'size_mb': 0.001003,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic0'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-03-13_02-16-02_UTC.txt',
#    'name': '2020-03-13_02-16-02_UTC.txt',
#    'size_mb': 0.000359,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic0'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-03-21_18-38-25_UTC.txt',
#    'name': '2020-03-21_18-38-25_UTC.txt',
#    'size_mb': 0.00155,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic0'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-04-12_15-53-52_UTC.txt',
#    'name': '2020-04-12_15-53-52_UTC.txt',
#    'size_mb': 0.000625,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic0'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-04-13_18-28-50_UTC.txt',
#    'name': '2020-04-13_18-28-50_UTC.txt',
#    'size_mb': 0.001881,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic0'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-04-16_19-36-24_UTC.txt',
#    'name': '2020-04-16_19-36-24_UTC.txt',
#    'size_mb': 0.001123,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic0'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-05-06_20-11-05_UTC.txt',
#    'name': '2020-05-06_20-11-05_UTC.txt',
#    'size_mb': 0.002165,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic0'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-05-11_21-14-36_UTC.txt',
#    'name': '2020-05-11_21-14-36_UTC.txt',
#    'size_mb': 0.001811,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic0'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-06-08_19-54-27_UTC.txt',
#    'name': '2020-06-08_19-54-27_UTC.txt',
#    'size_mb': 2.1e-05,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic0'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-06-17_15-41-51_UTC.txt',
#    'name': '2020-06-17_15-41-51_UTC.txt',
#    'size_mb': 0.00123,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic0'}],
#  'feel-relationship-trauma-people-bond': [{'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-01-18_16-06-09_UTC.txt',
#    'name': '2019-01-18_16-06-09_UTC.txt',
#    'size_mb': 0.00089,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'extension': 'txt',
#    'label': 'topic1'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-02-01_23-24-26_UTC.txt',
#    'name': '2019-02-01_23-24-26_UTC.txt',
#    'size_mb': 0.00136,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 22),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 22),
#    'extension': 'txt',
#    'label': 'topic1'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-03-11_18-50-08_UTC.txt',
#    'name': '2019-03-11_18-50-08_UTC.txt',
#    'size_mb': 0.002095,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 22),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 22),
#    'extension': 'txt',
#    'label': 'topic1'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-04-01_12-58-42_UTC.txt',
#    'name': '2019-04-01_12-58-42_UTC.txt',
#    'size_mb': 0.001397,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 22),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 22),
#    'extension': 'txt',
#    'label': 'topic1'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-04-09_13-07-11_UTC.txt',
#    'name': '2019-04-09_13-07-11_UTC.txt',
#    'size_mb': 0.00089,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 22),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 22),
#    'extension': 'txt',
#    'label': 'topic1'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-05-18_12-08-02_UTC.txt',
#    'name': '2019-05-18_12-08-02_UTC.txt',
#    'size_mb': 0.001424,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'extension': 'txt',
#    'label': 'topic1'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-06-11_13-02-58_UTC.txt',
#    'name': '2019-06-11_13-02-58_UTC.txt',
#    'size_mb': 0.001864,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'extension': 'txt',
#    'label': 'topic1'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-06-17_12-35-18_UTC.txt',
#    'name': '2019-06-17_12-35-18_UTC.txt',
#    'size_mb': 0.001866,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'extension': 'txt',
#    'label': 'topic1'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-07-11_20-47-03_UTC.txt',
#    'name': '2019-07-11_20-47-03_UTC.txt',
#    'size_mb': 0.000972,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'extension': 'txt',
#    'label': 'topic1'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-08-27_18-11-19_UTC.txt',
#    'name': '2019-08-27_18-11-19_UTC.txt',
#    'size_mb': 0.001685,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'extension': 'txt',
#    'label': 'topic1'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-10-07_12-48-39_UTC.txt',
#    'name': '2019-10-07_12-48-39_UTC.txt',
#    'size_mb': 0.00209,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic1'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-10-10_18-17-59_UTC.txt',
#    'name': '2019-10-10_18-17-59_UTC.txt',
#    'size_mb': 0.001676,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic1'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-10-19_13-25-24_UTC.txt',
#    'name': '2019-10-19_13-25-24_UTC.txt',
#    'size_mb': 0.001646,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic1'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-11-13_14-36-57_UTC.txt',
#    'name': '2019-11-13_14-36-57_UTC.txt',
#    'size_mb': 0.001566,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic1'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-01-20_15-12-50_UTC.txt',
#    'name': '2020-01-20_15-12-50_UTC.txt',
#    'size_mb': 0.000825,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic1'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-02-06_18-47-59_UTC.txt',
#    'name': '2020-02-06_18-47-59_UTC.txt',
#    'size_mb': 0.001566,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic1'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-02-14_03-29-03_UTC.txt',
#    'name': '2020-02-14_03-29-03_UTC.txt',
#    'size_mb': 0.000666,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic1'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-02-22_20-19-20_UTC.txt',
#    'name': '2020-02-22_20-19-20_UTC.txt',
#    'size_mb': 0.001759,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic1'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-03-06_21-41-07_UTC.txt',
#    'name': '2020-03-06_21-41-07_UTC.txt',
#    'size_mb': 0.001139,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic1'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-03-26_18-24-13_UTC.txt',
#    'name': '2020-03-26_18-24-13_UTC.txt',
#    'size_mb': 0.001998,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic1'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-03-31_20-55-48_UTC.txt',
#    'name': '2020-03-31_20-55-48_UTC.txt',
#    'size_mb': 0.001741,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic1'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-04-04_17-35-26_UTC.txt',
#    'name': '2020-04-04_17-35-26_UTC.txt',
#    'size_mb': 0.002083,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic1'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-04-05_02-04-10_UTC.txt',
#    'name': '2020-04-05_02-04-10_UTC.txt',
#    'size_mb': 0.001346,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic1'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-04-16_17-04-23_UTC.txt',
#    'name': '2020-04-16_17-04-23_UTC.txt',
#    'size_mb': 0.002107,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic1'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-04-21_21-28-04_UTC.txt',
#    'name': '2020-04-21_21-28-04_UTC.txt',
#    'size_mb': 0.001368,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic1'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-04-25_20-46-25_UTC.txt',
#    'name': '2020-04-25_20-46-25_UTC.txt',
#    'size_mb': 0.001595,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic1'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-04-30_15-41-32_UTC.txt',
#    'name': '2020-04-30_15-41-32_UTC.txt',
#    'size_mb': 0.002112,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic1'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-05-08_20-48-25_UTC.txt',
#    'name': '2020-05-08_20-48-25_UTC.txt',
#    'size_mb': 0.001611,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic1'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-05-22_02-37-25_UTC.txt',
#    'name': '2020-05-22_02-37-25_UTC.txt',
#    'size_mb': 5.2e-05,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic1'}],
#  'self-feel-people-behavior-know': [{'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2018-12-21_22-04-15_UTC.txt',
#    'name': '2018-12-21_22-04-15_UTC.txt',
#    'size_mb': 0.000938,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'extension': 'txt',
#    'label': 'topic2'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-04-04_13-31-40_UTC.txt',
#    'name': '2019-04-04_13-31-40_UTC.txt',
#    'size_mb': 0.001559,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 22),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 22),
#    'extension': 'txt',
#    'label': 'topic2'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-05-23_21-51-03_UTC.txt',
#    'name': '2019-05-23_21-51-03_UTC.txt',
#    'size_mb': 0.001355,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'extension': 'txt',
#    'label': 'topic2'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-06-19_13-14-10_UTC.txt',
#    'name': '2019-06-19_13-14-10_UTC.txt',
#    'size_mb': 0.000465,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'extension': 'txt',
#    'label': 'topic2'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-06-26_12-45-30_UTC.txt',
#    'name': '2019-06-26_12-45-30_UTC.txt',
#    'size_mb': 0.000942,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'extension': 'txt',
#    'label': 'topic2'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-07-02_19-44-36_UTC.txt',
#    'name': '2019-07-02_19-44-36_UTC.txt',
#    'size_mb': 0.001294,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'extension': 'txt',
#    'label': 'topic2'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-07-29_22-15-17_UTC.txt',
#    'name': '2019-07-29_22-15-17_UTC.txt',
#    'size_mb': 5.6e-05,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'extension': 'txt',
#    'label': 'topic2'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-08-29_12-55-57_UTC.txt',
#    'name': '2019-08-29_12-55-57_UTC.txt',
#    'size_mb': 0.00154,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'extension': 'txt',
#    'label': 'topic2'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-11-11_13-22-50_UTC.txt',
#    'name': '2019-11-11_13-22-50_UTC.txt',
#    'size_mb': 0.001571,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic2'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-11-17_21-22-53_UTC.txt',
#    'name': '2019-11-17_21-22-53_UTC.txt',
#    'size_mb': 0.00035,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic2'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-11-25_16-44-09_UTC.txt',
#    'name': '2019-11-25_16-44-09_UTC.txt',
#    'size_mb': 0.001341,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic2'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-12-03_01-38-56_UTC.txt',
#    'name': '2019-12-03_01-38-56_UTC.txt',
#    'size_mb': 0.001901,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic2'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-12-06_16-25-15_UTC.txt',
#    'name': '2019-12-06_16-25-15_UTC.txt',
#    'size_mb': 0.001058,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic2'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-12-11_15-30-01_UTC.txt',
#    'name': '2019-12-11_15-30-01_UTC.txt',
#    'size_mb': 0.001673,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic2'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-12-20_14-04-33_UTC.txt',
#    'name': '2019-12-20_14-04-33_UTC.txt',
#    'size_mb': 0.000659,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic2'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-01-06_17-22-55_UTC.txt',
#    'name': '2020-01-06_17-22-55_UTC.txt',
#    'size_mb': 0.001265,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic2'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-01-14_22-02-56_UTC.txt',
#    'name': '2020-01-14_22-02-56_UTC.txt',
#    'size_mb': 0.000673,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic2'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-01-21_14-41-24_UTC.txt',
#    'name': '2020-01-21_14-41-24_UTC.txt',
#    'size_mb': 0.000481,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic2'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-01-23_17-32-58_UTC.txt',
#    'name': '2020-01-23_17-32-58_UTC.txt',
#    'size_mb': 0.001721,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic2'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-03-07_23-31-28_UTC.txt',
#    'name': '2020-03-07_23-31-28_UTC.txt',
#    'size_mb': 0.001888,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic2'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-03-28_01-08-27_UTC.txt',
#    'name': '2020-03-28_01-08-27_UTC.txt',
#    'size_mb': 0.001548,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic2'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-04-27_22-17-53_UTC.txt',
#    'name': '2020-04-27_22-17-53_UTC.txt',
#    'size_mb': 0.002159,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic2'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-05-01_13-55-29_UTC.txt',
#    'name': '2020-05-01_13-55-29_UTC.txt',
#    'size_mb': 0.000883,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic2'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-05-05_23-49-10_UTC.txt',
#    'name': '2020-05-05_23-49-10_UTC.txt',
#    'size_mb': 0.001153,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic2'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-05-17_15-23-40_UTC.txt',
#    'name': '2020-05-17_15-23-40_UTC.txt',
#    'size_mb': 0.001243,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic2'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-05-25_16-32-31_UTC.txt',
#    'name': '2020-05-25_16-32-31_UTC.txt',
#    'size_mb': 0.002062,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic2'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-06-05_17-53-07_UTC.txt',
#    'name': '2020-06-05_17-53-07_UTC.txt',
#    'size_mb': 3.4e-05,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic2'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-06-18_00-33-31_UTC.txt',
#    'name': '2020-06-18_00-33-31_UTC.txt',
#    'size_mb': 3.9e-05,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic2'}],
#  'emotion-emotional-addiction-feel-body': [{'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2018-07-26_00-37-54_UTC.txt',
#    'name': '2018-07-26_00-37-54_UTC.txt',
#    'size_mb': 0.000564,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 20),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 20),
#    'extension': 'txt',
#    'label': 'topic3'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2018-08-03_00-24-18_UTC.txt',
#    'name': '2018-08-03_00-24-18_UTC.txt',
#    'size_mb': 0.000485,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 20),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 20),
#    'extension': 'txt',
#    'label': 'topic3'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2018-08-08_15-59-52_UTC.txt',
#    'name': '2018-08-08_15-59-52_UTC.txt',
#    'size_mb': 0.000735,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 20),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 20),
#    'extension': 'txt',
#    'label': 'topic3'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2018-10-04_17-08-24_UTC.txt',
#    'name': '2018-10-04_17-08-24_UTC.txt',
#    'size_mb': 0.001502,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'extension': 'txt',
#    'label': 'topic3'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2018-10-08_18-33-56_UTC.txt',
#    'name': '2018-10-08_18-33-56_UTC.txt',
#    'size_mb': 0.00091,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'extension': 'txt',
#    'label': 'topic3'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2018-11-13_01-08-18_UTC.txt',
#    'name': '2018-11-13_01-08-18_UTC.txt',
#    'size_mb': 0.000343,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'extension': 'txt',
#    'label': 'topic3'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2018-11-27_15-37-48_UTC.txt',
#    'name': '2018-11-27_15-37-48_UTC.txt',
#    'size_mb': 0.001599,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'extension': 'txt',
#    'label': 'topic3'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2018-12-03_21-48-54_UTC.txt',
#    'name': '2018-12-03_21-48-54_UTC.txt',
#    'size_mb': 0.001016,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'extension': 'txt',
#    'label': 'topic3'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2018-12-05_15-35-24_UTC.txt',
#    'name': '2018-12-05_15-35-24_UTC.txt',
#    'size_mb': 0.001539,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'extension': 'txt',
#    'label': 'topic3'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2018-12-08_15-12-37_UTC.txt',
#    'name': '2018-12-08_15-12-37_UTC.txt',
#    'size_mb': 0.001512,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'extension': 'txt',
#    'label': 'topic3'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-01-08_16-52-32_UTC.txt',
#    'name': '2019-01-08_16-52-32_UTC.txt',
#    'size_mb': 0.001607,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'extension': 'txt',
#    'label': 'topic3'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-01-15_15-47-18_UTC.txt',
#    'name': '2019-01-15_15-47-18_UTC.txt',
#    'size_mb': 0.000421,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'extension': 'txt',
#    'label': 'topic3'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-01-30_00-05-21_UTC.txt',
#    'name': '2019-01-30_00-05-21_UTC.txt',
#    'size_mb': 0.00079,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'extension': 'txt',
#    'label': 'topic3'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-02-18_23-36-28_UTC.txt',
#    'name': '2019-02-18_23-36-28_UTC.txt',
#    'size_mb': 0.000974,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 22),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 22),
#    'extension': 'txt',
#    'label': 'topic3'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-03-18_17-39-55_UTC.txt',
#    'name': '2019-03-18_17-39-55_UTC.txt',
#    'size_mb': 0.001697,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 22),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 22),
#    'extension': 'txt',
#    'label': 'topic3'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-04-06_13-06-45_UTC.txt',
#    'name': '2019-04-06_13-06-45_UTC.txt',
#    'size_mb': 0.001798,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 22),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 22),
#    'extension': 'txt',
#    'label': 'topic3'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-05-24_13-49-02_UTC.txt',
#    'name': '2019-05-24_13-49-02_UTC.txt',
#    'size_mb': 0.00177,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'extension': 'txt',
#    'label': 'topic3'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-05-25_14-37-11_UTC.txt',
#    'name': '2019-05-25_14-37-11_UTC.txt',
#    'size_mb': 0.001359,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'extension': 'txt',
#    'label': 'topic3'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-06-05_12-36-24_UTC.txt',
#    'name': '2019-06-05_12-36-24_UTC.txt',
#    'size_mb': 0.001372,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'extension': 'txt',
#    'label': 'topic3'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-06-09_19-28-19_UTC.txt',
#    'name': '2019-06-09_19-28-19_UTC.txt',
#    'size_mb': 0.00162,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'extension': 'txt',
#    'label': 'topic3'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-06-16_02-13-37_UTC.txt',
#    'name': '2019-06-16_02-13-37_UTC.txt',
#    'size_mb': 0.000763,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'extension': 'txt',
#    'label': 'topic3'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-07-28_23-06-37_UTC.txt',
#    'name': '2019-07-28_23-06-37_UTC.txt',
#    'size_mb': 0.000264,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'extension': 'txt',
#    'label': 'topic3'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-09-03_14-54-35_UTC.txt',
#    'name': '2019-09-03_14-54-35_UTC.txt',
#    'size_mb': 0.001713,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'extension': 'txt',
#    'label': 'topic3'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-11-08_18-46-05_UTC.txt',
#    'name': '2019-11-08_18-46-05_UTC.txt',
#    'size_mb': 0.001249,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic3'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-02-24_22-06-02_UTC.txt',
#    'name': '2020-02-24_22-06-02_UTC.txt',
#    'size_mb': 0.000223,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic3'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-02-28_15-49-21_UTC.txt',
#    'name': '2020-02-28_15-49-21_UTC.txt',
#    'size_mb': 0.001458,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic3'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-03-09_23-13-21_UTC.txt',
#    'name': '2020-03-09_23-13-21_UTC.txt',
#    'size_mb': 0.001065,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic3'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-03-24_17-57-45_UTC.txt',
#    'name': '2020-03-24_17-57-45_UTC.txt',
#    'size_mb': 0.002095,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic3'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-04-02_19-53-00_UTC.txt',
#    'name': '2020-04-02_19-53-00_UTC.txt',
#    'size_mb': 0.001142,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic3'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-04-08_00-56-49_UTC.txt',
#    'name': '2020-04-08_00-56-49_UTC.txt',
#    'size_mb': 0.000222,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic3'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-04-26_20-01-44_UTC.txt',
#    'name': '2020-04-26_20-01-44_UTC.txt',
#    'size_mb': 0.002019,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic3'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-05-02_17-22-23_UTC.txt',
#    'name': '2020-05-02_17-22-23_UTC.txt',
#    'size_mb': 0.001114,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic3'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-05-10_00-34-35_UTC.txt',
#    'name': '2020-05-10_00-34-35_UTC.txt',
#    'size_mb': 0.001073,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic3'}],
#  'story-word-create-self-people': [{'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2018-08-19_15-51-05_UTC.txt',
#    'name': '2018-08-19_15-51-05_UTC.txt',
#    'size_mb': 0.000574,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 20),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 20),
#    'extension': 'txt',
#    'label': 'topic4'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2018-09-07_23-51-04_UTC.txt',
#    'name': '2018-09-07_23-51-04_UTC.txt',
#    'size_mb': 0.000437,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 20),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 20),
#    'extension': 'txt',
#    'label': 'topic4'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2018-09-25_18-03-45_UTC.txt',
#    'name': '2018-09-25_18-03-45_UTC.txt',
#    'size_mb': 0.001809,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'extension': 'txt',
#    'label': 'topic4'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2018-10-01_22-45-36_UTC.txt',
#    'name': '2018-10-01_22-45-36_UTC.txt',
#    'size_mb': 0.000936,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'extension': 'txt',
#    'label': 'topic4'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2018-10-09_15-39-28_UTC.txt',
#    'name': '2018-10-09_15-39-28_UTC.txt',
#    'size_mb': 0.001268,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'extension': 'txt',
#    'label': 'topic4'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2018-10-16_17-54-49_UTC.txt',
#    'name': '2018-10-16_17-54-49_UTC.txt',
#    'size_mb': 0.001399,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'extension': 'txt',
#    'label': 'topic4'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2018-10-24_15-26-50_UTC.txt',
#    'name': '2018-10-24_15-26-50_UTC.txt',
#    'size_mb': 0.000604,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'extension': 'txt',
#    'label': 'topic4'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2018-10-24_23-34-26_UTC.txt',
#    'name': '2018-10-24_23-34-26_UTC.txt',
#    'size_mb': 0.00069,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'extension': 'txt',
#    'label': 'topic4'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2018-10-30_13-51-43_UTC.txt',
#    'name': '2018-10-30_13-51-43_UTC.txt',
#    'size_mb': 0.000597,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'extension': 'txt',
#    'label': 'topic4'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2018-11-17_23-55-39_UTC.txt',
#    'name': '2018-11-17_23-55-39_UTC.txt',
#    'size_mb': 0.00059,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'extension': 'txt',
#    'label': 'topic4'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2018-11-19_13-27-08_UTC.txt',
#    'name': '2018-11-19_13-27-08_UTC.txt',
#    'size_mb': 0.000745,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'extension': 'txt',
#    'label': 'topic4'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2018-12-03_00-01-40_UTC.txt',
#    'name': '2018-12-03_00-01-40_UTC.txt',
#    'size_mb': 0.000617,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'extension': 'txt',
#    'label': 'topic4'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2018-12-08_23-23-26_UTC.txt',
#    'name': '2018-12-08_23-23-26_UTC.txt',
#    'size_mb': 0.00066,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'extension': 'txt',
#    'label': 'topic4'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2018-12-11_23-08-28_UTC.txt',
#    'name': '2018-12-11_23-08-28_UTC.txt',
#    'size_mb': 0.001139,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'extension': 'txt',
#    'label': 'topic4'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2018-12-23_00-56-45_UTC.txt',
#    'name': '2018-12-23_00-56-45_UTC.txt',
#    'size_mb': 0.000659,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'extension': 'txt',
#    'label': 'topic4'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2018-12-26_21-38-54_UTC.txt',
#    'name': '2018-12-26_21-38-54_UTC.txt',
#    'size_mb': 0.001258,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'extension': 'txt',
#    'label': 'topic4'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2018-12-27_20-49-16_UTC.txt',
#    'name': '2018-12-27_20-49-16_UTC.txt',
#    'size_mb': 0.00116,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'extension': 'txt',
#    'label': 'topic4'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-01-10_15-28-16_UTC.txt',
#    'name': '2019-01-10_15-28-16_UTC.txt',
#    'size_mb': 0.00075,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'extension': 'txt',
#    'label': 'topic4'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-01-13_15-37-19_UTC.txt',
#    'name': '2019-01-13_15-37-19_UTC.txt',
#    'size_mb': 0.00092,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'extension': 'txt',
#    'label': 'topic4'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-04-01_22-59-56_UTC.txt',
#    'name': '2019-04-01_22-59-56_UTC.txt',
#    'size_mb': 0.001797,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 22),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 22),
#    'extension': 'txt',
#    'label': 'topic4'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-05-08_17-19-53_UTC.txt',
#    'name': '2019-05-08_17-19-53_UTC.txt',
#    'size_mb': 0.000258,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'extension': 'txt',
#    'label': 'topic4'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-09-05_19-16-46_UTC.txt',
#    'name': '2019-09-05_19-16-46_UTC.txt',
#    'size_mb': 0.001256,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'extension': 'txt',
#    'label': 'topic4'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-09-30_12-49-12_UTC.txt',
#    'name': '2019-09-30_12-49-12_UTC.txt',
#    'size_mb': 0.001456,
# ...
#    'label': 'topic18'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-11-20_20-39-50_UTC.txt',
#    'name': '2019-11-20_20-39-50_UTC.txt',
#    'size_mb': 0.000309,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic18'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-11-27_15-30-04_UTC.txt',
#    'name': '2019-11-27_15-30-04_UTC.txt',
#    'size_mb': 0.001465,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic18'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-01-08_21-39-22_UTC.txt',
#    'name': '2020-01-08_21-39-22_UTC.txt',
#    'size_mb': 0.001793,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic18'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-01-09_14-32-43_UTC.txt',
#    'name': '2020-01-09_14-32-43_UTC.txt',
#    'size_mb': 0.001314,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic18'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-02-13_19-44-12_UTC.txt',
#    'name': '2020-02-13_19-44-12_UTC.txt',
#    'size_mb': 0.000724,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic18'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-03-08_18-53-20_UTC.txt',
#    'name': '2020-03-08_18-53-20_UTC.txt',
#    'size_mb': 0.002103,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic18'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-03-10_17-02-03_UTC.txt',
#    'name': '2020-03-10_17-02-03_UTC.txt',
#    'size_mb': 0.001164,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic18'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-03-17_03-01-06_UTC.txt',
#    'name': '2020-03-17_03-01-06_UTC.txt',
#    'size_mb': 0.000276,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic18'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-04-08_21-32-45_UTC.txt',
#    'name': '2020-04-08_21-32-45_UTC.txt',
#    'size_mb': 0.001742,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic18'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-04-13_21-19-23_UTC.txt',
#    'name': '2020-04-13_21-19-23_UTC.txt',
#    'size_mb': 0.001822,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic18'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-05-28_19-18-21_UTC.txt',
#    'name': '2020-05-28_19-18-21_UTC.txt',
#    'size_mb': 0.001699,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic18'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-05-29_15-42-41_UTC.txt',
#    'name': '2020-05-29_15-42-41_UTC.txt',
#    'size_mb': 0.001263,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic18'}],
#  'parent-trauma-self-work-child': [{'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-01-13_23-37-50_UTC.txt',
#    'name': '2019-01-13_23-37-50_UTC.txt',
#    'size_mb': 0.000611,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 21),
#    'extension': 'txt',
#    'label': 'topic19'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-05-23_12-39-48_UTC.txt',
#    'name': '2019-05-23_12-39-48_UTC.txt',
#    'size_mb': 0.001415,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'extension': 'txt',
#    'label': 'topic19'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-06-15_14-14-00_UTC.txt',
#    'name': '2019-06-15_14-14-00_UTC.txt',
#    'size_mb': 0.001261,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'extension': 'txt',
#    'label': 'topic19'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-07-12_13-06-31_UTC.txt',
#    'name': '2019-07-12_13-06-31_UTC.txt',
#    'size_mb': 0.00177,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'extension': 'txt',
#    'label': 'topic19'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-07-14_17-02-58_UTC.txt',
#    'name': '2019-07-14_17-02-58_UTC.txt',
#    'size_mb': 0.001274,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'extension': 'txt',
#    'label': 'topic19'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-09-17_20-04-43_UTC.txt',
#    'name': '2019-09-17_20-04-43_UTC.txt',
#    'size_mb': 0.001526,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'extension': 'txt',
#    'label': 'topic19'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-09-25_12-34-16_UTC.txt',
#    'name': '2019-09-25_12-34-16_UTC.txt',
#    'size_mb': 0.001099,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 23),
#    'extension': 'txt',
#    'label': 'topic19'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-10-15_17-20-55_UTC.txt',
#    'name': '2019-10-15_17-20-55_UTC.txt',
#    'size_mb': 0.001651,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic19'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-10-29_13-39-06_UTC.txt',
#    'name': '2019-10-29_13-39-06_UTC.txt',
#    'size_mb': 0.001258,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic19'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-12-09_21-21-37_UTC.txt',
#    'name': '2019-12-09_21-21-37_UTC.txt',
#    'size_mb': 0.001347,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic19'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2019-12-19_13-34-26_UTC.txt',
#    'name': '2019-12-19_13-34-26_UTC.txt',
#    'size_mb': 0.001456,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic19'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-01-24_15-21-32_UTC.txt',
#    'name': '2020-01-24_15-21-32_UTC.txt',
#    'size_mb': 0.001993,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic19'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-01-28_15-33-14_UTC.txt',
#    'name': '2020-01-28_15-33-14_UTC.txt',
#    'size_mb': 0.00171,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic19'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-01-31_22-46-57_UTC.txt',
#    'name': '2020-01-31_22-46-57_UTC.txt',
#    'size_mb': 0.002142,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 24),
#    'extension': 'txt',
#    'label': 'topic19'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-02-26_18-42-32_UTC.txt',
#    'name': '2020-02-26_18-42-32_UTC.txt',
#    'size_mb': 0.000617,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic19'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-03-23_16-56-31_UTC.txt',
#    'name': '2020-03-23_16-56-31_UTC.txt',
#    'size_mb': 0.001691,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic19'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-03-26_00-52-51_UTC.txt',
#    'name': '2020-03-26_00-52-51_UTC.txt',
#    'size_mb': 0.001326,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic19'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-04-01_01-41-55_UTC.txt',
#    'name': '2020-04-01_01-41-55_UTC.txt',
#    'size_mb': 0.000105,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic19'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-04-01_19-52-48_UTC.txt',
#    'name': '2020-04-01_19-52-48_UTC.txt',
#    'size_mb': 0.001607,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic19'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-04-06_21-51-33_UTC.txt',
#    'name': '2020-04-06_21-51-33_UTC.txt',
#    'size_mb': 0.001077,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic19'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-04-07_15-45-28_UTC.txt',
#    'name': '2020-04-07_15-45-28_UTC.txt',
#    'size_mb': 0.002022,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic19'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-04-08_19-15-08_UTC.txt',
#    'name': '2020-04-08_19-15-08_UTC.txt',
#    'size_mb': 0.001451,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic19'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-04-28_21-08-39_UTC.txt',
#    'name': '2020-04-28_21-08-39_UTC.txt',
#    'size_mb': 0.001795,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic19'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-05-07_15-54-54_UTC.txt',
#    'name': '2020-05-07_15-54-54_UTC.txt',
#    'size_mb': 0.002115,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic19'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-05-10_14-43-41_UTC.txt',
#    'name': '2020-05-10_14-43-41_UTC.txt',
#    'size_mb': 0.001678,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic19'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-05-11_15-06-03_UTC.txt',
#    'name': '2020-05-11_15-06-03_UTC.txt',
#    'size_mb': 0.001043,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic19'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-05-12_18-54-18_UTC.txt',
#    'name': '2020-05-12_18-54-18_UTC.txt',
#    'size_mb': 0.001738,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic19'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-05-13_22-28-03_UTC.txt',
#    'name': '2020-05-13_22-28-03_UTC.txt',
#    'size_mb': 0.001402,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic19'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-05-16_00-18-16_UTC.txt',
#    'name': '2020-05-16_00-18-16_UTC.txt',
#    'size_mb': 0.000861,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic19'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-06-10_14-19-43_UTC.txt',
#    'name': '2020-06-10_14-19-43_UTC.txt',
#    'size_mb': 0.001801,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic19'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-06-10_18-10-56_UTC.txt',
#    'name': '2020-06-10_18-10-56_UTC.txt',
#    'size_mb': 0.001057,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic19'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-06-18_16-54-13_UTC.txt',
#    'name': '2020-06-18_16-54-13_UTC.txt',
#    'size_mb': 0.001901,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic19'},
#   {'parent_folder': '../data/test_case5/',
#    'absolute_path': '../data/test_case5/2020-06-21_00-42-34_UTC.txt',
#    'name': '2020-06-21_00-42-34_UTC.txt',
#    'size_mb': 0.001791,
#    'created_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'last_modified_on': datetime.datetime(2020, 9, 14, 10, 25, 25),
#    'extension': 'txt',
#    'label': 'topic19'}]}

# %%
pickle.dump(topic_files, open('../app/data/test5.pkl', 'wb'))

# %% [raw]
# cursor = curr_files_db.find({})
# entries = list(cursor)
#
# text_files = [
#     file for file in entries if file['extension'] in formats['text']]
#
# raw_docs = [extract_text(file) for file in text_files]
#
# doc_labels = labels(raw_docs)
# if doc_labels == 404:
#     return redirect(url_for('index'))
# else:
#     for idx, file in enumerate(text_files):
#         text_files[idx]['topic'] = doc_labels[idx]
#
#     topic_files = get_topic_files(text_files)
#     topic_names = name_cluster_labels_common(
#         custom_sw, topic_files, words=8)
