# %%
from tika import parser
import os
import re
import multiprocessing as mp
import concurrent.futures as cf
from functools import partial
import sys

# %%
from tika import parser
parser.from_file(i['absolute_path'], service='text')['content']

# %%
sys.setrecursionlimit(10000)

# %%
data_path = '../data/t5/'
data_folder = os.listdir(data_path)

# %%
len(data_folder)
# Out:
# 4458

# %%
files = []

for ext in {re.search('(\.\w+)', file).group(0) for file in data_folder if (file != '.DS_Store')}:
    filenames = [f for f in data_folder if f.endswith(ext)]
    files.extend(filenames)

# %%
text_ext = ['ppt', 'pptx', 'doc', 'docx', 'odt', 'pdf', 'rtf', 'text', 'txt', 'wpd', 'ods', 'xls', 'xlsm', 'xlsx']

# %%
text_files = [f for f in files if (f.split('.')[1] in text_ext)]
len(text_files)
# Out:
# 2935

# %%
files[:10]
# Out:
# ['000056.html',
#  '000057.html',
#  '000059.html',
#  '000060.html',
#  '000063.html',
#  '000064.html',
#  '000065.html',
#  '000066.html',
#  '000067.html',
#  '000069.html']

# %%
# %%timeit
texts_core = {}

for i in files:
    texts_core[data_path + i] = parser.from_file(data_path + i, service='text')['content']
# Out:
# 2020-09-12 18:58:08,324 [MainThread  ] [WARNI]  Tika server returned status: 422
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-b84cca40baf0> in <module>
# ----> 1 get_ipython().run_cell_magic('timeit', '', "texts_core = {}\n\nfor i in files:\n    texts_core[data_path + i] = parser.from_file(data_path + i, service='text')['content']\n")
#
# ~/anaconda3/envs/ds/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2360             with self.builtin_trap:
#    2361                 args = (magic_arg_s, cell)
# -> 2362                 result = fn(*args, **kwargs)
#    2363             return result
#    2364
#
# <decorator-gen-60> in timeit(self, line, cell, local_ns)
#
# ~/anaconda3/envs/ds/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
# ...

# %%
texts_core['../data/t5/000030.xls'][:100]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-d295c1d57cfc> in <module>
# ----> 1 texts_core['../data/t5/000030.xls'][:100]
#
# NameError: name 'texts_core' is not defined

# %% [raw]
# %%timeit
# texts_mp = {}
# processes = []
#
# for i in files[:10]:
#     p = mp.Process(target=parser.from_file, args=[data_path + i, 'text'])
#     p.start()
#     texts_mp[data_path + i] = p
#     processes.append(p)
#
# for process in processes:
#     process.join()

# %% [raw]
# return_dict.keys()

# %% [raw]
# stuff = map(lambda f: data_path + f, files[:10])
# pool = mp.Pool()

# %% [raw]
# def parse_text(file):
#     text = parser.from_file(file, service='text')['content'].replace('\n', ' ')
#     return text

# %% [raw]
# %%timeit
# pool = Pool(processes=10)
# results = pool.map(parse_text, stuff)

# %% [raw]
# all_stuff = map(lambda f: data_path + f, files[:10])
# stuff = map(lambda f: data_path + f, files[:10])
# n_cores = mp.cpu_count()

# %% [raw]
# %%timeit
# n_cores = mp.cpu_count()
# pool = mp.Pool(n_cores)
# #all_results = pool.map(parse_text, all_stuff)
# results = pool.map(parse_text, stuff)
#
# pool.close()
# pool.join()

# %% [raw]
# results = cf.ProcessPoolExecutor().map(lambda file: parser.from_file(file, service='text')['content'], stuff)

# %% [raw]
# #%%timeit
# with cf.ProcessPoolExecutor() as executor:
#     executor.map(lambda file: parser.from_file(file, service='text')['content'], all_stuff)

# %% [raw]
# from __future__ import print_function
# count = 0
# for i in results:
#     print(next(i))

# %% [raw]
# from __future__ import print_function
# next(results)

# %%
text_ext = ['ppt',
 'pptx',
 'doc',
 'docx',
 'odt',
 'pdf',
 'rtf',
 'text',
 'txt',
 'wpd',
 'ods',
 'xls',
 'xlsm',
 'xlsx']

# %%
parser.from_file('/Users/faustina/METIS/BOOTCAMPWORK/baseballdata/AllstarFull.csv', service='text')['content']
# Out:
# '\tplayerID\tyearID\tgameNum\tgameID\tteamID\tlgID\tGP\tstartingPos\n\tgomezle01\t1933\t0\tALS193307060\tNYA\tAL\t1\t1\n\tferreri01\t1933\t0\tALS193307060\tBOS\tAL\t1\t2\n\tgehrilo01\t1933\t0\tALS193307060\tNYA\tAL\t1\t3\n\tgehrich01\t1933\t0\tALS193307060\tDET\tAL\t1\t4\n\tdykesji01\t1933\t0\tALS193307060\tCHA\tAL\t1\t5\n\tcronijo01\t1933\t0\tALS193307060\tWS1\tAL\t1\t6\n\tchapmbe01\t1933\t0\tALS193307060\tNYA\tAL\t1\t7\n\tsimmoal01\t1933\t0\tALS193307060\tCHA\tAL\t1\t8\n\truthba01\t1933\t0\tALS193307060\tNYA\tAL\t1\t9\n\tdickebi01\t1933\t0\tALS193307060\tNYA\tAL\t0\t\n\tferrewe01\t1933\t0\tALS193307060\tCLE\tAL\t0\t\n\tfoxxji01\t1933\t0\tALS193307060\tPHA\tAL\t0\t\n\thildeor01\t1933\t0\tALS193307060\tCLE\tAL\t0\t\n\tlazzeto01\t1933\t0\tALS193307060\tNYA\tAL\t0\t\n\taveriea01\t1933\t0\tALS193307060\tCLE\tAL\t1\t\n\tcrowdal01\t1933\t0\tALS193307060\tWS1\tAL\t1\t\n\tgrovele01\t1933\t0\tALS193307060\tPHA\tAL\t1\t\n\twestsa01\t1933\t0\tALS193307060\tSLA\tAL\t1\t\n\thallabi01\t1933\t0\tA
# ...

# %%
import datetime
files = [{'absolute_path': '/Users/faustina/METIS/BOOTCAMPWORK/Books_n_Cheatsheets/BDA3.pdf', 'created_on': datetime.datetime(2020, 6, 27, 14, 11, 10), 'extension': 'pdf', 'last_modified_on': datetime.datetime(2020, 6, 27, 14, 11, 25), 'name': 'BDA3.pdf', 'parent_folder': '/Users/faustina/METIS/BOOTCAMPWORK/Books_n_Cheatsheets/', 'size_mb': 78.145894, 'text': '\nThis electronic edition is for non-commercial purposes only.\n\nBayesian Data Analysis\nThird edition\n', 'topic': 5}, {'absolute_path': '/Users/faustina/METIS/BOOTCAMPWORK/Books_n_Cheatsheets/CRACKING the · CODING INTERVIEW ( PDFDrive.com ).pdf', 'created_on': datetime.datetime(2020, 7, 23, 8, 12, 51), 'extension': 'pdf', 'last_modified_on': datetime.datetime(2020, 7, 23, 8, 13, 31), 'name': 'CRACKING the · CODING INTERVIEW ( PDFDrive.com ).pdf', 'parent_folder': '/Users/faustina/METIS/BOOTCAMPWORK/Books_n_Cheatsheets/', 'size_mb': 56.423124, 'text': '\nCRACKING \n��the ��· \n\nCODING INTERVIEW \n189 PROGRAMMING Q!JESTIONS & SOLUTIONS \n\n\n\nCRACKING \nthe \n\n', 'topic': 7}, {'absolute_path': '/Users/faustina/METIS/BOOTCAMPWORK/Books_n_Cheatsheets/Deep Learning with Python.pdf', 'created_on': datetime.datetime(2020, 8, 26, 10, 55, 2), 'extension': 'pdf', 'last_modified_on': datetime.datetime(2020, 8, 26, 10, 55, 2), 'name': 'Deep Learning with Python.pdf', 'parent_folder': '/Users/faustina/METIS/BOOTCAMPWORK/Books_n_Cheatsheets/', 'size_mb': 11.437542, 'text': '\nM A N N I N G\n\nFrançois Chollet\n\n\n\nDeep Learning with Python\nLicensed to   <null>\n\n\n\nLicensed to   ', 'topic': 0}, {'absolute_path': '/Users/faustina/METIS/BOOTCAMPWORK/Books_n_Cheatsheets/Flask_Web_Development_Developing.pdf', 'created_on': datetime.datetime(2020, 9, 5, 12, 3, 39), 'extension': 'pdf', 'last_modified_on': datetime.datetime(2020, 9, 5, 12, 3, 41), 'name': 'Flask_Web_Development_Developing.pdf', 'parent_folder': '/Users/faustina/METIS/BOOTCAMPWORK/Books_n_Cheatsheets/', 'size_mb': 8.846933, 'text': '\n\n\n\n\nMiguel Grinberg\n\nFlask Web Development\n\n\n\nFlask Web Development\nby Miguel Grinberg\n\nCopyright ©', 'topic': 6}, {'absolute_path': '/Users/faustina/METIS/BOOTCAMPWORK/Books_n_Cheatsheets/LaTeX_symbols.pdf', 'created_on': datetime.datetime(2020, 6, 23, 18, 35, 52), 'extension': 'pdf', 'last_modified_on': datetime.datetime(2020, 6, 23, 18, 35, 52), 'name': 'LaTeX_symbols.pdf', 'parent_folder': '/Users/faustina/METIS/BOOTCAMPWORK/Books_n_Cheatsheets/', 'size_mb': 0.471414, 'text': '\nThe Great, Big List of LATEX Symbols\n\nDavid Carlisle Scott Pakin Alexander Holt\n\nFebruary 7, 2001\n\n', 'topic': 0}, {'absolute_path': '/Users/faustina/METIS/BOOTCAMPWORK/Books_n_Cheatsheets/Math--Bertsekas_Tsitsiklis_Introduction_to_probability.pdf', 'created_on': datetime.datetime(2020, 6, 19, 17, 50, 58), 'extension': 'pdf', 'last_modified_on': datetime.datetime(2020, 6, 19, 17, 50, 58), 'name': 'Math--Bertsekas_Tsitsiklis_Introduction_to_probability.pdf', 'parent_folder': '/Users/faustina/METIS/BOOTCAMPWORK/Books_n_Cheatsheets/', 'size_mb': 2.138294, 'text': '\nLECTURE NOTES\n\nCourse 6.041-6.431\n\nM.I.T.\n\nFALL 2000\n\nIntroduction to Probability\n\nDimitri P. Berts', 'topic': 3}, {'absolute_path': '/Users/faustina/METIS/BOOTCAMPWORK/Books_n_Cheatsheets/MovieSuccessPredictionusingHistoricalandCurrentDataMining.pdf', 'created_on': datetime.datetime(2020, 7, 15, 11, 26, 48), 'extension': 'pdf', 'last_modified_on': datetime.datetime(2020, 7, 15, 11, 26, 48), 'name': 'MovieSuccessPredictionusingHistoricalandCurrentDataMining.pdf', 'parent_folder': '/Users/faustina/METIS/BOOTCAMPWORK/Books_n_Cheatsheets/', 'size_mb': 0.455383, 'text': '\nSee discussions, stats, and author profiles for this publication at: https://www.researchgate.net/p', 'topic': 4}, {'absolute_path': '/Users/faustina/METIS/BOOTCAMPWORK/Books_n_Cheatsheets/Powell_1999_ROC.pdf', 'created_on': datetime.datetime(2020, 7, 22, 11, 9, 52), 'extension': 'pdf', 'last_modified_on': datetime.datetime(2020, 7, 22, 11, 9, 52), 'name': 'Powell_1999_ROC.pdf', 'parent_folder': '/Users/faustina/METIS/BOOTCAMPWORK/Books_n_Cheatsheets/', 'size_mb': 1.100978, 'text': '\nAJR:173, October 1999 889\n\nFilm-Screen Versus Digitized\nMammography: Assessment of Clinical\nEquival', 'topic': 9}, {'absolute_path': '/Users/faustina/METIS/BOOTCAMPWORK/Books_n_Cheatsheets/Practitioner Workflow for Classification.pdf', 'created_on': datetime.datetime(2020, 7, 24, 16, 24, 48), 'extension': 'pdf', 'last_modified_on': datetime.datetime(2020, 7, 24, 16, 24, 48), 'name': 'Practitioner Workflow for Classification.pdf', 'parent_folder': '/Users/faustina/METIS/BOOTCAMPWORK/Books_n_Cheatsheets/', 'size_mb': 0.069628, 'text': '\n How to build and test a classification model \n \nRules are helpful, but they must be combined with ', 'topic': 8}, {'absolute_path': '/Users/faustina/METIS/BOOTCAMPWORK/Books_n_Cheatsheets/Practitioner Workflow for Linear Regression Fitting_v2.pdf', 'created_on': datetime.datetime(2020, 7, 9, 11, 44, 48), 'extension': 'pdf', 'last_modified_on': datetime.datetime(2020, 7, 9, 11, 44, 48), 'name': 'Practitioner Workflow for Linear Regression Fitting_v2.pdf', 'parent_folder': '/Users/faustina/METIS/BOOTCAMPWORK/Books_n_Cheatsheets/', 'size_mb': 0.062513, 'text': '\n How to build and test a linear regression model \n \nRules are helpful, but they must be combined wi', 'topic': 0}, {'absolute_path': '/Users/faustina/METIS/BOOTCAMPWORK/Books_n_Cheatsheets/regression_model_breakdown - Sheet1.pdf', 'created_on': datetime.datetime(2020, 7, 20, 11, 13, 40), 'extension': 'pdf', 'last_modified_on': datetime.datetime(2020, 7, 20, 11, 13, 41), 'name': 'regression_model_breakdown - Sheet1.pdf', 'parent_folder': '/Users/faustina/METIS/BOOTCAMPWORK/Books_n_Cheatsheets/', 'size_mb': 0.082007, 'text': '\nLinear \nRegression \n(OLS)\n\nPolynomial \nRegression Ridge Lasso Decision Trees\n\nRandom Forest \n& Grad', 'topic': 2}, {'absolute_path': '/Users/faustina/METIS/BOOTCAMPWORK/Books_n_Cheatsheets/Trevor-Sullivan-VI-Shortcuts.pdf', 'created_on': datetime.datetime(2020, 6, 21, 10, 59, 6), 'extension': 'pdf', 'last_modified_on': datetime.datetime(2020, 6, 21, 10, 59, 7), 'name': 'Trevor-Sullivan-VI-Shortcuts.pdf', 'parent_folder': '/Users/faustina/METIS/BOOTCAMPWORK/Books_n_Cheatsheets/', 'size_mb': 0.389382, 'text': '\nMac OS X :: VI Keyboard Shortcut Cheat Sheet  http://trevorsullivan.net  \n\nhttp://trevorsullivan.ne', 'topic': 1}]

# %%
len(files)
# Out:
# 27

# %%
[f for f in files if (f['extension'] in text_ext)]
# Out:
# [{'absolute_path': '/Users/faustina/METIS/BOOTCAMPWORK/Books_n_Cheatsheets/BDA3.pdf',
#   'created_on': datetime.datetime(2020, 6, 27, 14, 11, 10),
#   'extension': 'pdf',
#   'last_modified_on': datetime.datetime(2020, 6, 27, 14, 11, 25),
#   'name': 'BDA3.pdf',
#   'parent_folder': '/Users/faustina/METIS/BOOTCAMPWORK/Books_n_Cheatsheets/',
#   'size_mb': 78.145894,
#   'text': '\nThis electronic edition is for non-commercial purposes only.\n\nBayesian Data Analysis\nThird edition\n',
#   'topic': 5},
#  {'absolute_path': '/Users/faustina/METIS/BOOTCAMPWORK/Books_n_Cheatsheets/CRACKING the · CODING INTERVIEW ( PDFDrive.com ).pdf',
#   'created_on': datetime.datetime(2020, 7, 23, 8, 12, 51),
#   'extension': 'pdf',
#   'last_modified_on': datetime.datetime(2020, 7, 23, 8, 13, 31),
#   'name': 'CRACKING the · CODING INTERVIEW ( PDFDrive.com ).pdf',
#   'parent_folder': '/Users/faustina/METIS/BOOTCAMPWORK/Books_n_Cheatsheets/',
#   'size_mb': 56.423124,
# ...

# %%
from collections import defaultdict, Counter

def get_topic_files(files):
    topic_files = defaultdict(list)

    for file in files:
        topic_files[file['topic']].append(file)

    topic_files = dict(topic_files)
    
    return topic_files

# %%
topics = get_topic_files(files)

# %%
topics.keys()
# Out:
# dict_keys([5, 7, 0, 6, 3, 4, 9, 8, 2, 1])

# %%
def name_cluster_labels_common(sw, topic_files, words=8):
    cluster_names = {}
    
    for i in topic_files.keys():
        label_text = ' '.join([file['text'] for file in topic_files[i]])
        corpus = re.findall('[a-zA-Z]{4,}', label_text)
        corpus = [w for w in corpus if (w.lower() not in sw)]
        label_dict = Counter(corpus)
        cluster_names[i] = '-'.join([w[0] for w in label_dict.most_common(words)])
    
    return cluster_names

# %%
topic_names = name_cluster_labels_common(sw, topic_files, words=8)

# %%
for k in topics.keys():
    print(topic_names[k])
# Out:
# edition-electronic-commercial-purposes-Bayesian-Data-Analysis-Third
# CRACKING-CODING-INTERVIEW-PROGRAMMING-JESTIONS-SOLUTIONS
# Licensed-Fran-Chollet-Deep-Learning-Python-null-Great
# Miguel-Grinberg-Flask-Development-Copyright
# LECTURE-NOTES-Course-FALL-Introduction-Probability-Dimitri-Berts
# discussions-stats-author-profiles-publication-https-researchgate
# October-Film-Screen-Versus-Digitized-Mammography-Assessment-Clinical
# build-test-classification-model-Rules-helpful-must-combined
# Regression-Linear-Polynomial-Ridge-Lasso-Decision-Trees-Random
# http-trevorsullivan-Keyboard-Shortcut-Cheat-Sheet
